# %%
import numpy as np
import pandas as pd

# %%
class CorruptQueue:
    
    def __init__(self, officeinput, outfile):
        
        self.SupervisorPresent = False
        self.RegularQueue = []
        self.VIPStack = []
        
        self.inpfile = open(officeinput, 'r')
        self.inpactions = self.inpfile.readlines()
        self.inpactions = [s.replace("\n", "") for s in self.inpactions]
        self.inpactions = [s.split(",") for s in self.inpactions]
        self.outfile = open(outfile, 'w')

        for s in self.inpactions:
            if s[0] == 'lineup':
                if self.SupervisorPresent == True:
                    print('{1} client {0} lines up at RegularQueue'.format(s[1],s[2]), file=self.outfile)
                    self.RegularQueue.append(s[1])
                else:
                    if s[2] == 'VIP':
                        print('{1} client {0} lines up at VIPStack'.format(s[1],s[2]), file=self.outfile)
                        self.VIPStack.append(s[1])
                    else:
                        print('{1} client {0} lines up at RegularQueue'.format(s[1],s[2]), file=self.outfile)
                        self.RegularQueue.append(s[1])
            elif s[0] == 'serve':
                if len(self.RegularQueue) == 0 and len(self.VIPStack) == 0:
                    print('No one in queue', file=self.outfile)
                else:
                    if self.SupervisorPresent == True or len(self.VIPStack) == 0:
                        name = self.RegularQueue[0]
                        print('Now serving {} from RegularQueue'.format(name), file=self.outfile)
                        self.RegularQueue = self.RegularQueue[1:]
                    else:
                        name = self.VIPStack[-1]
                        print('Now serving {} from VIPStack'.format(name), file=self.outfile)
                        self.VIPStack = self.VIPStack[:-1]
            elif s[0] == 'arrive':
                print('Supervisor present', file=self.outfile)
                self.SupervisorPresent = True
                self.RegularQueue += self.VIPStack
                self.VIPStack = []
            elif s[0] == 'leave':
                print('Supervisor not here', file=self.outfile)
                self.SupervisorPresent = False
        
        self.inpfile.close()
        self.outfile.close()
                
                
Sample = CorruptQueue('officeinput.txt', 'officeoutput.txt')
with open('officeoutput.txt','r') as Sampleout:
    print(Sampleout.read())
# Out:
# regular client John lines up at RegularQueue
# regular client Bob lines up at RegularQueue
# regular client Tom lines up at RegularQueue
# VIP client Sarah lines up at VIPStack
# VIP client Marie lines up at VIPStack
# VIP client Joan lines up at VIPStack
# Now serving Joan from VIPStack
# Now serving Marie from VIPStack
# Supervisor present
# Now serving John from RegularQueue
# Now serving Bob from RegularQueue
# Now serving Tom from RegularQueue
# VIP client Bea lines up at RegularQueue
# regular client Hank lines up at RegularQueue
# Now serving Sarah from RegularQueue
# Now serving Bea from RegularQueue
# Now serving Hank from RegularQueue
# Supervisor not here
# regular client Art lines up at RegularQueue
# VIP client Daisy lines up at VIPStack
# regular client Marius lines up at RegularQueue
# VIP client Dane lines up at VIPStack
# Now serving Dane from VIPStack
# Supervisor present
# Now serving Art from RegularQueue
# Now serving Marius from RegularQueue
# Now serving Daisy from RegularQueue
# Supervisor not here

# %%
lamb = 1
mu = 0.7
sigma = 0.3
limit = 50

arrivals = [0]
for i in range(limit):
    arrivals.append(arrivals[i]+np.random.exponential(lamb))
    
print([np.round(s,2) for s in arrivals])

serves = []
for ar in range(limit):
    serve = np.random.normal(mu,sigma)
    serves.append(serve)
    
print([np.round(s,2) for s in serves])
        
    
time = 0
arrived = 0
served = 0
queue = 0
event = 'arrival'
server = 'idle'

for i in range(limit):
    nextarrival = arrivals[i+1]
    if event == 'arrival':
        arrived += 1
        if server == 'busy':
            print('new customer queues')
            queue += 1
        else:
            print('customer is served')
            served += 1
            servetime = arrivals[i] + serves[i]
    else:
        print('customer departs')
        if queue == 0:
            print('server is idle')
            server = 'idle'
        else:
            queue -= 1
            print('customer in queue is served')
            servetime = arrivals[i] + serves[i]
    if nextarrival <= servetime:
        event = 'arrival'
        server = 'busy'
    else:
        event = 'departure'
        server = 'idle'
        
    print(arrived, served, queue, np.round(time,2), event, server)
# Out:
# [0, 0.68, 1.1, 1.38, 1.72, 2.22, 8.11, 9.02, 9.87, 10.47, 10.65, 11.57, 12.4, 12.55, 12.6, 14.08, 17.41, 18.25, 18.65, 20.64, 21.67, 22.94, 23.9, 24.43, 25.15, 25.23, 26.83, 27.63, 28.19, 29.17, 29.36, 29.47, 29.54, 29.92, 30.5, 31.23, 31.45, 33.41, 33.42, 36.4, 37.4, 39.59, 39.83, 40.14, 40.49, 42.45, 45.08, 47.46, 47.93, 50.7, 50.82]
# [0.15, 0.63, 0.81, 1.03, 1.12, 0.62, 0.67, 1.75, 0.64, 0.77, 0.57, 0.85, 0.62, 0.72, 0.87, 0.54, 1.14, 1.04, 0.53, 0.86, 0.6, 0.75, 0.55, 0.98, 1.0, 0.56, 0.79, 1.25, 0.73, 0.38, 0.89, 0.71, 0.91, 0.74, 0.5, 0.27, 0.94, 0.85, 1.13, 0.89, 1.09, 1.11, 0.79, 0.67, 0.51, 0.41, 0.22, 0.51, 1.15, 1.3]
# customer is served
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle
# customer departs
# server is idle
# 1 1 0 0 departure idle

# %%
class CQSimulation:
    def __init__(self, lamb, mu, sigma, outfile):
        
        self.lamb = lamb
        self.mu = mu
        self.sigma = sigma
        self.outfile = open(outfile, 'w')
        
        
        self.clock = 0.0 #simulation clock
        self.arrived = 0 #total no of arrivals
        self.served = 0 #total no served
        self.arrivalTime = self.gen_arrival() #time of next arrival
        self.serveTime = float('inf') #departure time
        self.serveSum = 0 #sum of service times
        self.serverState = 'idle' #idle or busy
        self.waitSum = 0.0 #total wait time
        self.queue = 0 #current queue
        self.queueTotal = 0 #total no of customers who had to queue
        
    def time_adv(self):
        # advance time to next event, whether time of next arrival or departure of current customer
        nextEvent = min(self.arrivalTime, self.serveTime)
        # add waiting time of customers between events to total wait time
        self.waitSum += (self.queueTotal*(nextEvent - self.clock))
        # then, advance time
        self.clock = nextEvent
        
        # choose arrival or departure depending on next event
        if self.arrivalTime<self.serveTime:
            self.arrival()
        elif self.serveTime<self.arrivalTime:
            self.departure()
    
    def arrival(self):
        self.arrived += 1
                        
        if self.queue == 0:
            # if no one is in queue, but the server is busy, add 1 to queue
            if self.serverState == 'busy':
                print('New customer begins queue at {}'.format(np.round(self.clock,2)), file=self.outfile)
                self.queue += 1
                self.queueTotal += 1
                # generate next arrival time
                self.arrivalTime = self.clock + self.gen_arrival()
            # else, customer is served: server switches from idle to busy
            else:
                print('New customer is served at {}'.format(np.round(self.clock,2)), file=self.outfile)
                self.serverState = 'busy'
                # generate service period, increment sum of service periods, generate next arrival and departure time
                self.serve = self.gen_serve()
                self.serveSum += self.serve
                self.serveTime = self.clock + self.serve
                self.arrivalTime = self.clock + self.gen_arrival()
        else:
            # if there are people in queue, new customer lines up
            print('New customer lines up at {}'.format(np.round(self.clock,2)), file=self.outfile)
            self.queue += 1
            self.queueTotal += 1
            # generate next arrival time
            self.arrivalTime = self.clock + self.gen_arrival()
    
    def departure(self):
        self.served += 1
        # if people are in queue, next person in queue is served. generate service period and next departure time
        if self.queue > 0:
            print('Customer departs, customer in queue no. {1} is served at {0}'.format(np.round(self.clock,2), self.queue), file=self.outfile)
            self.serve = self.gen_serve()
            self.serveSum += self.serve
            self.serveTime = self.clock + self.serve
            self.queue -= 1
        # else, server stays idle
        else:
            print('Customer departs at {}'.format(np.round(self.clock,2)), file=self.outfile)
            self.serveTime = float('inf')
            self.serverState = 'idle'
    
    def gen_arrival(self):
        return np.random.exponential(self.lamb)
    
    def gen_serve(self):
        return np.random.normal(self.mu, self.sigma)
                        
s = CQSimulation(1, 0.7, 0.3, 'simoutput.txt')
while s.arrived <= 100:
    s.time_adv()

s.outfile.close()
print(open('simoutput.txt', 'r').read())
# Out:
# New customer is served at 2.3
# New customer begins queue at 2.66
# New customer lines up at 2.76
# Customer departs, customer in queue no. 2 is served at 3.39
# Customer departs, customer in queue no. 1 is served at 3.81
# New customer begins queue at 3.9
# New customer lines up at 4.28
# Customer departs, customer in queue no. 2 is served at 4.43
# Customer departs, customer in queue no. 1 is served at 5.11
# New customer begins queue at 5.15
# Customer departs, customer in queue no. 1 is served at 5.7
# Customer departs at 6.48
# New customer is served at 8.38
# Customer departs at 9.23
# New customer is served at 9.39
# New customer begins queue at 9.53
# Customer departs, customer in queue no. 1 is served at 10.03
# New customer begins queue at 10.2
# Customer departs, customer in queue no. 1 is served at 10.27
# Customer departs at 10.62
# New customer is served at 10.65
# New customer begins queue at 10.8
# New customer lines up at 11.5
# Customer departs, customer in queue no. 2 is served at 11.67
# Customer departs, customer in queue no. 1 is served at 11.91
# Customer departs at 12.63
# New customer is served at 14.07
# Customer departs at 14.57
# New customer is served at 15.11
# New customer begins queue at 15.56
# Customer departs, customer in queue no. 1 is served at 16.12
# Customer departs at 16.31
# New customer is served at 18.63
# Customer departs at 18.99
# New customer is served at 19.51
# New customer begins queue at 20.06
# Customer departs, customer in queue no. 1 is served at 20.44
# Customer departs at 20.67
# New customer is served at 20.89
# New customer begins queue at 21.73
# Customer departs, customer in queue no. 1 is served at 21.96
# Customer departs at 22.38
# New customer is served at 23.14
# Customer departs at 24.18
# New customer is served at 25.12
# New customer begins queue at 25.39
# Customer departs, customer in queue no. 1 is served at 25.96
# New customer begins queue at 26.7
# Customer departs, customer in queue no. 1 is served at 26.7
# New customer begins queue at 26.91
# New customer lines up at 26.93
# Customer departs, customer in queue no. 2 is served at 27.1
# New customer lines up at 27.24
# New customer lines up at 27.67
# Customer departs, customer in queue no. 3 is served at 28.02
# Customer departs, customer in queue no. 2 is served at 28.81
# Customer departs, customer in queue no. 1 is served at 29.94
# Customer departs at 30.67
# New customer is served at 30.89
# Customer departs at 31.39
# New customer is served at 31.45
# Customer departs at 31.66
# New customer is served at 31.72
# Customer departs at 32.22
# New customer is served at 33.71
# New customer begins queue at 34.32
# Customer departs, customer in queue no. 1 is served at 34.54
# New customer begins queue at 35.11
# Customer departs, customer in queue no. 1 is served at 35.38
# New customer begins queue at 35.68
# Customer departs, customer in queue no. 1 is served at 36.44
# Customer departs at 37.06
# New customer is served at 38.08
# New customer begins queue at 38.28
# Customer departs, customer in queue no. 1 is served at 38.87
# New customer begins queue at 39.63
# Customer departs, customer in queue no. 1 is served at 39.73
# New customer begins queue at 41.32
# New customer lines up at 41.44
# Customer departs, customer in queue no. 2 is served at 41.45
# Customer departs, customer in queue no. 1 is served at 42.17
# Customer departs at 42.99
# New customer is served at 43.33
# Customer departs at 43.97
# New customer is served at 44.49
# New customer begins queue at 44.93
# New customer lines up at 45.12
# New customer lines up at 45.5
# New customer lines up at 45.6
# Customer departs, customer in queue no. 4 is served at 45.61
# New customer lines up at 46.03
# Customer departs, customer in queue no. 4 is served at 46.09
# Customer departs, customer in queue no. 3 is served at 46.65
# New customer lines up at 47.34
# Customer departs, customer in queue no. 3 is served at 47.5
# New customer lines up at 48.4
# Customer departs, customer in queue no. 3 is served at 48.62
# Customer departs, customer in queue no. 2 is served at 49.03
# New customer lines up at 49.48
# Customer departs, customer in queue no. 2 is served at 49.61
# New customer lines up at 49.72
# New customer lines up at 49.98
# New customer lines up at 50.18
# New customer lines up at 50.2
# New customer lines up at 50.29
# Customer departs, customer in queue no. 6 is served at 50.34
# New customer lines up at 50.88
# New customer lines up at 50.92
# New customer lines up at 51.25
# Customer departs, customer in queue no. 8 is served at 51.43
# Customer departs, customer in queue no. 7 is served at 52.5
# Customer departs, customer in queue no. 6 is served at 52.99
# New customer lines up at 53.77
# Customer departs, customer in queue no. 6 is served at 54.7
# New customer lines up at 55.05
# Customer departs, customer in queue no. 6 is served at 55.24
# New customer lines up at 55.62
# Customer departs, customer in queue no. 6 is served at 55.95
# Customer departs, customer in queue no. 5 is served at 56.37
# Customer departs, customer in queue no. 4 is served at 56.62
# New customer lines up at 56.74
# Customer departs, customer in queue no. 4 is served at 56.84
# Customer departs, customer in queue no. 3 is served at 57.6
# New customer lines up at 57.97
# Customer departs, customer in queue no. 3 is served at 58.16
# Customer departs, customer in queue no. 2 is served at 58.79
# New customer lines up at 59.28
# New customer lines up at 59.35
# Customer departs, customer in queue no. 3 is served at 59.66
# New customer lines up at 60.2
# New customer lines up at 60.29
# New customer lines up at 60.49
# New customer lines up at 60.64
# Customer departs, customer in queue no. 6 is served at 60.82
# Customer departs, customer in queue no. 5 is served at 61.21
# Customer departs, customer in queue no. 4 is served at 61.93
# New customer lines up at 62.05
# Customer departs, customer in queue no. 4 is served at 62.82
# Customer departs, customer in queue no. 3 is served at 63.25
# New customer lines up at 63.73
# Customer departs, customer in queue no. 3 is served at 64.23
# Customer departs, customer in queue no. 2 is served at 64.78
# New customer lines up at 64.95
# Customer departs, customer in queue no. 2 is served at 65.75
# Customer departs, customer in queue no. 1 is served at 66.74
# New customer begins queue at 66.78
# New customer lines up at 66.93
# New customer lines up at 67.21
# Customer departs, customer in queue no. 3 is served at 67.85
# Customer departs, customer in queue no. 2 is served at 68.42
# Customer departs, customer in queue no. 1 is served at 68.81
# Customer departs at 69.18
# New customer is served at 69.22
# Customer departs at 69.64
# New customer is served at 69.64
# New customer begins queue at 70.27
# Customer departs, customer in queue no. 1 is served at 70.51
# Customer departs at 71.18
# New customer is served at 71.86
# New customer begins queue at 72.06
# New customer lines up at 72.48
# Customer departs, customer in queue no. 2 is served at 72.73
# Customer departs, customer in queue no. 1 is served at 72.68
# Customer departs at 72.99
# New customer is served at 74.14
# Customer departs at 74.88
# New customer is served at 77.55
# Customer departs at 78.51
# New customer is served at 79.41
# Customer departs at 80.01
# New customer is served at 81.38
# Customer departs at 82.26
# New customer is served at 82.56
# New customer begins queue at 82.86
# New customer lines up at 82.87
# Customer departs, customer in queue no. 2 is served at 83.28
# New customer lines up at 83.56
# Customer departs, customer in queue no. 2 is served at 84.03
# New customer lines up at 84.25
# New customer lines up at 84.41
# Customer departs, customer in queue no. 3 is served at 84.58
# New customer lines up at 84.62
# Customer departs, customer in queue no. 3 is served at 85.56
# New customer lines up at 85.81
# Customer departs, customer in queue no. 3 is served at 86.17
# New customer lines up at 86.21
# Customer departs, customer in queue no. 3 is served at 86.81
# New customer lines up at 87.43
# Customer departs, customer in queue no. 3 is served at 87.55
# Customer departs, customer in queue no. 2 is served at 88.35
# New customer lines up at 88.57
# New customer lines up at 89.22
# New customer lines up at 89.38
# Customer departs, customer in queue no. 4 is served at 89.43
# Customer departs, customer in queue no. 3 is served at 90.02
# New customer lines up at 90.57
# Customer departs, customer in queue no. 3 is served at 90.64
# New customer lines up at 90.72

# %%
df=pd.DataFrame(columns=[
    'Average interarrival time',
    'Average service time',
    'Utilization',
    'People who had to wait in line',
    'Average wait time'])    
for i in range(100):
    np.random.seed(i)
    s.__init__(1, 1.2, 0.3, 'dumpoutput.txt')
    while s.arrived <= 100 :
        s.time_adv() 
    a=pd.Series([
        s.clock/s.arrived,
        s.serveSum/s.served,
        s.serveSum/s.clock,
        s.queueTotal,
        s.waitSum/s.queueTotal],index=df.columns)
    df=df.append(a,ignore_index=True)  
df
# Out:
#     Average interarrival time  Average service time  Utilization  \
# 0                    0.932952              1.282167     0.979707
# 1                    0.975697              1.232219     1.000326
# 2                    0.916821              1.155931     0.998657
# 3                    0.907988              1.252112     0.996701
# 4                    1.070460              1.219959     0.970402
# ..                        ...                   ...          ...
# 95                   0.997294              1.242158     0.974226
# 96                   1.088262              1.189741     1.006654
# 97                   1.041471              1.201539     0.959508
# 98                   1.044285              1.185255     0.955191
# 99                   1.071589              1.206013     1.002871
#
#     People who had to wait in line  Average wait time
# 0                             98.0          45.267195
# 1                            100.0          50.437823
# 2                            100.0          46.069102
# 3                             99.0          49.611272
# 4                            100.0          55.941278
# ..                             ...                ...
# 95                            97.0          48.502476
# 96                           100.0          61.634950
# 97                            98.0          50.815704
# 98                            97.0          49.768052
# 99                           100.0          54.214823
#
# [100 rows x 5 columns]
