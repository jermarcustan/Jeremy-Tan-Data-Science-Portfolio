# %% [markdown]
# ### Programming Task No. 2
# ### Name: Jeremy Marcus Tan
# ### ID No: 204947

# %%
import numpy as np

# %%
def rowEchelonForm(M):

    M = M.copy().astype(float)  
    # Get the dimensions of the given matrix
    m, n = M.shape
    # Start with the first row of the matrix
    row = 0

    # zero out the entries one column at a time
    for col in range(n):
        if row >= m:
            break
        # check for nonzero value in the current column
        pivot_rows = np.where(M[row:, col] != 0)[0]
        if pivot_rows.size == 0:
            continue  
        
        pivot_row = pivot_rows[0] + row

        # Type 1 Operation: swap current row with pivot row
        if pivot_row != row:
            M[[row, pivot_row]] = M[[pivot_row, row]]

        # Type 3 Operation: add multiple (factor) of one row to another row
        for i in range(row + 1, m):
            factor = M[i, col] / M[row, col]
            M[i, col:] -= factor * M[row, col:]

        row += 1

    return M

# %%
import numpy as np

# Set a level of tolerance for near zero values due to floating point precision of numpy
def find_pivot_columns(M, tol=1e-10):
    pivots = []
    # Iterate through each row
    for row in M:
        # Find the first non-zero element in the row using tolerance
        nonzeros = np.where(np.abs(row) > tol)[0]  
        # If there are any non-zero elements, the first one is a pivot
        if len(nonzeros) > 0:
            pivot_col = nonzeros[0]
            if pivot_col not in pivots:
                # save the pivot column in a list
                pivots.append(pivot_col)
    
    return pivots

# %%
def basis_col_space(M):

    N = M.copy()
    
    # 1. reduce to row echelon form

    M_ref = rowEchelonForm(M)

    # 2. identify pivot columns

    pivot_cols = find_pivot_columns(M_ref)
    
    # 3. the corresponding columns of the original matrix form a basis for col(A)
    # return only the columns of M that form a basis for the column space
    return M[:, pivot_cols]

# %%
def Algorithm2_GramSchmidt(M):

    # First, get the basis of the image of the matrix M
    # M_basis contains the columns of M that form a basis for the image of M
    M_basis = basis_col_space(M)

    # Get the dimensions of M_basis
    m, n = M_basis.shape # here, n is the rank of M

    # Intermediate Matrix
    R = np.zeros((m,n))

    # Orthogonal Matrix
    Q = M_basis.copy()

    # Algorithm 2: Gram Schmidt

    # Iterate through the columns of M_basis
    for j in range(n):
        
        for i in range(j):
            
            # Compute the dot product between column j of M_basis and column i of Q
            R[i,j] = np.dot(M_basis[:, j], Q[:, i])
            
        # Get the square root of the squared norm of column j of M_basis subtracted by
        # the sum of the entries, r_kj squared for k from 0 to j - 1
        rjj = np.dot(M_basis[:, j], M_basis[:, j]) - sum(R[k,j]**2 for k in range(j))
        R[j,j] = np.sqrt(rjj)

        # Lastly, the orthonormal vector in the jth column of Q is calculated.
        Q[:, j] = ( M_basis[:, j] - sum(R[k,j] * Q[:, k] for k in range(j)) ) / R[j,j]

    return Q

# %%
# Test gram schmidt function using randomly generated 5 x 8 matrices of normally distributed numbers.
for z in range(5):

    print(f'Test Example {z+1} \n')
    M = np.random.rand(5,8)
    Q = Algorithm2_GramSchmidt(M)

    print(f'The given matrix is M = \n {M}')
    print(f'\n The resulting orthogonal matrix is Q = \n {Q} \n')

    # Q^TQ should be equal to the identity matrix.
    print("\n Q^TQ =?= I: ", np.allclose(Q.T @ Q, np.identity(Q.shape[0])))

    # Check if the dot product between the columns of Q is equal to zero. 
    for j in range(Q.shape[1]):
        for i in range(j):
            print(f'The dot product between columns {i} and {j} is {np.dot(Q[:, i], Q[:, j])}')

    print("\n")
    # Check if the norm of the columns of Q is equal to one.
    for j in range(Q.shape[1]):
        print(f'The norm of column {j} is {np.linalg.norm(Q[:, j])}')

    print("\n")
# Out:
# Test Example 1
#
# The given matrix is M =
#  [[0.89987852 0.94833965 0.49962255 0.48418268 0.30577358 0.1435298
#   0.44416298 0.0111147 ]
#  [0.18814087 0.37012065 0.47111152 0.84210178 0.44474014 0.1957609
#   0.61788562 0.89354437]
#  [0.96074687 0.78382657 0.83534224 0.89535601 0.88006047 0.97324944
#   0.65857669 0.54895779]
#  [0.72905911 0.10549764 0.32858254 0.33076901 0.2985423  0.83853358
#   0.67414497 0.75211387]
#  [0.73668907 0.01293769 0.15744449 0.62781644 0.66852494 0.82596721
#   0.84862199 0.22844753]]
#
#  The resulting orthogonal matrix is Q =
#  [[ 0.5337494   0.5174287  -0.61824026  0.06574776 -0.2466482 ]
#  [ 0.11159292  0.33597455  0.60733411  0.57117592 -0.42375874]
#  [ 0.56985255  0.2493272   0.43936456 -0.29827033  0.57541082]
#  [ 0.43243044 -0.45940151  0.18101207 -0.45385169 -0.60266694]
#  [ 0.43695604 -0.58836625 -0.15204497  0.61195487  0.25551544]]
#
#
#  Q^TQ =?= I:  True
# The dot product between columns 0 and 1 is 1.3877787807814457e-16
# The dot product between columns 0 and 2 is 1.6653345369377348e-16
# The dot product between columns 1 and 2 is -1.6653345369377348e-16
# The dot product between columns 0 and 3 is -7.771561172376096e-16
# The dot product between columns 1 and 3 is 0.0
# The dot product between columns 2 and 3 is 2.1094237467877974e-15
# The dot product between columns 0 and 4 is 3.885780586188048e-16
# The dot product between columns 1 and 4 is -5.551115123125783e-16
# The dot product between columns 2 and 4 is 2.220446049250313e-16
# The dot product between columns 3 and 4 is 1.1102230246251565e-15
#
#
# The norm of column 0 is 1.0
# The norm of column 1 is 0.9999999999999999
# The norm of column 2 is 0.999999999999999
# The norm of column 3 is 0.9999999999999997
# The norm of column 4 is 0.9999999999999979
#
#
# Test Example 2
#
# The given matrix is M =
#  [[0.10663374 0.94783931 0.49033089 0.61120678 0.62514523 0.5244611
#   0.90679303 0.69271968]
#  [0.66737337 0.06206812 0.01407991 0.95867618 0.31263386 0.37883207
#   0.52179624 0.06885805]
#  [0.90711643 0.59818508 0.34409811 0.05038429 0.15011492 0.4091182
#   0.34583242 0.16642113]
#  [0.56570597 0.44305978 0.85791558 0.04819253 0.38212314 0.94301485
#   0.84544796 0.92143585]
#  [0.41570471 0.82545804 0.31627763 0.19041434 0.26390203 0.72336523
#   0.17507317 0.25425676]]
#
#  The resulting orthogonal matrix is Q =
#  [[ 0.08009537  0.79010455  0.00370201  0.4424984   0.41653452]
#  [ 0.50128147 -0.38055803 -0.25880526  0.71983452 -0.13693274]
#  [ 0.68135871 -0.05111463 -0.22938526 -0.49087523  0.48945023]
#  [ 0.42491645  0.03164118  0.89024592  0.01034153 -0.16062411]
#  [ 0.31224661  0.47675625 -0.29639626 -0.2120566  -0.73646914]]
#
#
#  Q^TQ =?= I:  True
# The dot product between columns 0 and 1 is 5.551115123125783e-17
# The dot product between columns 0 and 2 is -8.326672684688674e-17
# The dot product between columns 1 and 2 is 3.0531133177191805e-16
# The dot product between columns 0 and 3 is -5.551115123125783e-17
# The dot product between columns 1 and 3 is 1.1102230246251565e-16
# The dot product between columns 2 and 3 is -1.1102230246251565e-16
# The dot product between columns 0 and 4 is -7.494005416219807e-16
# The dot product between columns 1 and 4 is -3.823330541052883e-15
# The dot product between columns 2 and 4 is 1.0547118733938987e-15
# The dot product between columns 3 and 4 is -1.7486012637846216e-15
#
#
# The norm of column 0 is 0.9999999999999999
# The norm of column 1 is 0.9999999999999999
# The norm of column 2 is 0.9999999999999999
# The norm of column 3 is 1.0
# The norm of column 4 is 1.0000000000000497
#
#
# Test Example 3
#
# The given matrix is M =
#  [[0.30646908 0.00239628 0.42465655 0.61006132 0.37197955 0.50128695
#   0.33132809 0.30798461]
#  [0.83581916 0.48686877 0.95887893 0.50750134 0.670742   0.29824342
#   0.43396496 0.86171846]
#  [0.84139362 0.80306339 0.7771255  0.42237099 0.57135002 0.92859881
#   0.88293315 0.0562725 ]
#  [0.40310065 0.95907236 0.77496851 0.3066001  0.73958781 0.40175229
#   0.14013796 0.66519575]
#  [0.57645888 0.92611536 0.24642331 0.51965963 0.91092243 0.06458073
#   0.68240852 0.91842523]]
#
#  The resulting orthogonal matrix is Q =
#  [[ 0.21696388 -0.37966012  0.22389484  0.83127294 -0.26007934]
#  [ 0.59171571 -0.43828041  0.21272867 -0.22351733  0.60213729]
#  [ 0.59566213 -0.05214804 -0.1554778  -0.35666069 -0.70077601]
#  [ 0.28537392  0.68902859  0.66290032  0.0651298   0.01107262]
#  [ 0.40810237  0.4316117  -0.66408391  0.35717861  0.2803209 ]]
#
#
#  Q^TQ =?= I:  True
# The dot product between columns 0 and 1 is 2.220446049250313e-16
# The dot product between columns 0 and 2 is 5.551115123125783e-17
# The dot product between columns 1 and 2 is -7.216449660063518e-16
# The dot product between columns 0 and 3 is 2.7755575615628914e-17
# The dot product between columns 1 and 3 is -4.440892098500626e-16
# The dot product between columns 2 and 3 is -1.3877787807814457e-17
# The dot product between columns 0 and 4 is -2.220446049250313e-16
# The dot product between columns 1 and 4 is 9.992007221626409e-16
# The dot product between columns 2 and 4 is 1.9984014443252818e-15
# The dot product between columns 3 and 4 is 1.0824674490095276e-15
#
#
# The norm of column 0 is 1.0
# The norm of column 1 is 0.9999999999999997
# The norm of column 2 is 0.9999999999999993
# The norm of column 3 is 0.9999999999999998
# The norm of column 4 is 1.0000000000000013
#
#
# Test Example 4
#
# The given matrix is M =
#  [[0.92993913 0.189763   0.5793711  0.41477149 0.6350393  0.28447627
#   0.5172879  0.04500789]
#  [0.36980348 0.75419566 0.975789   0.55923762 0.72188613 0.46287661
#   0.29328566 0.5344646 ]
#  [0.33084413 0.58155756 0.01091178 0.29292312 0.79663955 0.80161442
#   0.22132787 0.33892123]
#  [0.56063487 0.00915321 0.252966   0.43647744 0.22674422 0.5267981
#   0.89786464 0.69639457]
#  [0.49597418 0.47573905 0.28001398 0.36134429 0.21365972 0.87621486
#   0.27907722 0.09982611]]
#
#  The resulting orthogonal matrix is Q =
#  [[ 0.71932835 -0.36518269  0.1210327  -0.53854217  0.21102545]
#  [ 0.28605111  0.6679352   0.66924354  0.11881188  0.10017065]
#  [ 0.2559152   0.48593021 -0.67652667  0.05145477  0.48789683]
#  [ 0.43366339 -0.34625282  0.00682854  0.83093914  0.0392246 ]
#  [ 0.38364692  0.25393895 -0.28236363 -0.05242727 -0.84015011]]
#
#
#  Q^TQ =?= I:  True
# The dot product between columns 0 and 1 is 5.551115123125783e-17
# The dot product between columns 0 and 2 is -2.7755575615628914e-16
# The dot product between columns 1 and 2 is -5.551115123125783e-17
# The dot product between columns 0 and 3 is -8.326672684688674e-16
# The dot product between columns 1 and 3 is 1.3877787807814457e-16
# The dot product between columns 2 and 3 is 1.2628786905111156e-15
# The dot product between columns 0 and 4 is -1.1102230246251565e-16
# The dot product between columns 1 and 4 is 1.734723475976807e-16
# The dot product between columns 2 and 4 is 1.124100812432971e-15
# The dot product between columns 3 and 4 is 2.1441182163073336e-15
#
#
# The norm of column 0 is 1.0
# The norm of column 1 is 0.9999999999999999
# The norm of column 2 is 1.0000000000000002
# The norm of column 3 is 1.000000000000002
# The norm of column 4 is 1.0000000000000002
#
#
# Test Example 5
#
# The given matrix is M =
#  [[0.66150387 0.85530872 0.4915252  0.62944203 0.16862511 0.53752337
#   0.29347004 0.25676336]
#  [0.86680547 0.54483155 0.53939493 0.69450901 0.00127175 0.14324122
#   0.53225825 0.91318874]
#  [0.12583655 0.78836131 0.10952086 0.68075082 0.28570015 0.00363361
#   0.69895595 0.47763564]
#  [0.78103538 0.9671111  0.3542343  0.39728044 0.89570371 0.92483011
#   0.45706325 0.5502517 ]
#  [0.53956977 0.6013266  0.25347556 0.12220879 0.63992959 0.65882375
#   0.73469772 0.846193  ]]
#
#  The resulting orthogonal matrix is Q =
#  [[ 0.45583835  0.20298867  0.63679003 -0.54612723 -0.2173718 ]
#  [ 0.59731046 -0.4697616   0.26632832  0.57135767  0.15863129]
#  [ 0.08671322  0.83789389  0.14797505  0.46682957  0.22491818]
#  [ 0.5382068   0.18505603 -0.60954879  0.02666307 -0.55120509]
#  [ 0.3718143   0.0425175  -0.36072335 -0.39579627  0.75708016]]
#
#
#  Q^TQ =?= I:  True
# The dot product between columns 0 and 1 is -4.996003610813204e-16
# The dot product between columns 0 and 2 is -7.494005416219807e-16
# The dot product between columns 1 and 2 is 2.3314683517128287e-15
# The dot product between columns 0 and 3 is 6.106226635438361e-16
# The dot product between columns 1 and 3 is -3.164135620181696e-15
# The dot product between columns 2 and 3 is -3.0531133177191805e-16
# The dot product between columns 0 and 4 is -2.4452662117369073e-14
# The dot product between columns 1 and 4 is 4.2826853174915414e-14
# The dot product between columns 2 and 4 is -5.162537064506978e-14
# The dot product between columns 3 and 4 is 1.0462464228311319e-13
#
#
# The norm of column 0 is 1.0
# The norm of column 1 is 1.0000000000000004
# The norm of column 2 is 0.9999999999999997
# The norm of column 3 is 1.0000000000000033
# The norm of column 4 is 0.9999999999993165
