# %% [markdown]
# # Programming Task No. 2
# Luis Gabriel K. Villadarez
#
# 205377

# %%
import numpy as np

# Utility Function 

def basis (R):
    # Step 1: Extract the diagonal of R
    diagonal_entries = np.diag(R)
    
    # Step 2: Take the absolute value of each diagonal entry
    absolute_diagonal = np.abs(diagonal_entries)
    
    # Step 3: Compare each entry to a small threshold to determine independence
    independence_flags = absolute_diagonal > 1e-10
    
    # Step 4: Get the indices where the entry is considered independent
    independent_cols = np.where(independence_flags)[0]

    return independent_cols

    
# Main Function
def ModifiedGramSchmidt(M):
    """
    Algorithm 2: Modified Gram-Schmidt
    M = m x n matrix
    Qo = m x n orthonormal matrix
    Q = m x k matrix where k = rank(M) is the number of linearly independent columns of M
    Input: M
    Returns: Q
    """
    m, n = M.shape
    V = M.copy() # copy of original matrix M
    Qo = np.zeros((m, n))  # Initialize temporary matrix Qo to store orthonormalized vectors
    R = np.zeros((n, n))  # Initialize square upper triangular matrix R

    for j in range(n):
        for i in range(j):
            R[i, j] = np.dot(V[:, j], Qo[:, i]) # r_ij from pseudocode

        # r_jj from pseudocode
        # Define rjj_squared first before determining rjj to impose restriction for rjj_squared
        rjj_squared = np.dot(V[:, j], V[:, j]) - sum(R[k, j]**2 for k in range(j))
        R[j, j] = np.sqrt(rjj_squared) if rjj_squared > 1e-10 else 0.0 # to avoid very small negative number due to floating-point rounding error that will cause sqrt to be undefined

        if R[j, j] == 0: # to avoid division by zero
            Qo[:, j] = 0.0  # this column is linearly dependent and will be filtered out by utility function
        else:
            Qo[:, j] = (V[:, j] - sum(R[k, j] * Qo[:, k] for k in range(j))) / R[j, j] # u_j from pseudocode

    # Keep only independent columns (columns that correspond to a basis)
    independent_cols = basis(R) # final orthonormal basis must exclude those zero columns (not linearly ind) as they do not contribute to the column space
    Q = Qo[:, independent_cols]
    return Q

    
# Test Data

# Test Data
m = 5
n = 8

for i in range(5):
  M = np.random.rand(m, n)

  Q = ModifiedGramSchmidt(M)
  QT = np.transpose(Q)
  I = np.eye(M.shape[0])

  print("="*60)
  print(f'Test {i+1}\n')
  print('M=\n', M)
  print('\nQ=\n', Q)
  for j in range(Q.shape[1]):
        for i in range(j):
            print(f'The dot product between columns {i} and {j} is {np.dot(Q[:, i], Q[:, j])}')
        for j in range(Q.shape[1]):
            print(f'The norm of column {j} is {np.linalg.norm(Q[:, j])}')
  # Check if QQ^T = I
  print(f"\nQQ^T =?= I: {np.allclose(Q @ QT, I)}")

  # Calculate the average absolute error
  print(f"Average Absolute Error (QQ^T - I): {np.mean(np.abs(Q @ QT -I))}")
# Out:
# ============================================================
# Test 1
#
# M=
#  [[0.82508242 0.43849586 0.62026817 0.33409837 0.39814127 0.01061832
#   0.63777414 0.26449083]
#  [0.78701962 0.66900592 0.03409055 0.05661513 0.2810864  0.00267732
#   0.33354939 0.06894246]
#  [0.72546115 0.12677652 0.91359351 0.62304106 0.8708317  0.65667399
#   0.80703028 0.20774921]
#  [0.57685258 0.83113361 0.18574649 0.59882728 0.46956786 0.83745786
#   0.53490166 0.88242092]
#  [0.91504103 0.98806894 0.02912447 0.4307685  0.45062161 0.05453305
#   0.30414119 0.84032011]]
#
# Q=
#  [[ 0.47663858 -0.31375338  0.08861598 -0.6719651  -0.46366431]
#  [ 0.45465024  0.07113376 -0.59967851 -0.21620425  0.61795999]
#  [ 0.41908877 -0.65815516  0.32090208  0.47727563  0.24581744]
#  [ 0.33323968  0.55556797  0.6835998  -0.14283638  0.30427722]
#  [ 0.52860642  0.39328719 -0.24949159  0.50351204 -0.50013   ]]
# The norm of column 0 is 1.0
# The norm of column 1 is 0.9999999999999999
# The norm of column 2 is 1.0000000000000018
# The norm of column 3 is 1.0000000000000084
# The norm of column 4 is 1.0000000000000042
# The dot product between columns 0 and 1 is -1.535433191857062e-16
# The norm of column 0 is 1.0
# The norm of column 1 is 0.9999999999999999
# The norm of column 2 is 1.0000000000000018
# The norm of column 3 is 1.0000000000000084
# The norm of column 4 is 1.0000000000000042
# The dot product between columns 0 and 2 is -5.950009031028714e-16
# The dot product between columns 1 and 2 is 1.576383088718156e-16
# The norm of column 0 is 1.0
# The norm of column 1 is 0.9999999999999999
# The norm of column 2 is 1.0000000000000018
# The norm of column 3 is 1.0000000000000084
# The norm of column 4 is 1.0000000000000042
# The dot product between columns 0 and 3 is 9.462647236538803e-16
# The dot product between columns 1 and 3 is 4.705006044869491e-18
# The dot product between columns 2 and 3 is -6.097266784141396e-15
# The norm of column 0 is 1.0
# The norm of column 1 is 0.9999999999999999
# The norm of column 2 is 1.0000000000000018
# The norm of column 3 is 1.0000000000000084
# The norm of column 4 is 1.0000000000000042
# The dot product between columns 0 and 4 is -2.9790765281493035e-16
# The dot product between columns 1 and 4 is 5.026481727245702e-16
# The dot product between columns 2 and 4 is 7.433516075931687e-15
# The dot product between columns 3 and 4 is -2.5634914769812378e-14
# The norm of column 0 is 1.0
# The norm of column 1 is 0.9999999999999999
# The norm of column 2 is 1.0000000000000018
# The norm of column 3 is 1.0000000000000084
# The norm of column 4 is 1.0000000000000042
#
# QQ^T =?= I: True
# Average Absolute Error (QQ^T - I): 7.235780318145363e-15
# ============================================================
# Test 2
#
# M=
#  [[0.55389811 0.34191091 0.52618455 0.02258049 0.23245619 0.77257248
#   0.59813009 0.8342734 ]
#  [0.35352682 0.27417964 0.85179998 0.71649815 0.17880202 0.19681645
#   0.4322031  0.53135646]
#  [0.4317762  0.33740849 0.23849092 0.93639778 0.15943115 0.686632
#   0.00349264 0.91876413]
#  [0.48766347 0.6736705  0.96485123 0.66251747 0.21815722 0.11645456
#   0.01137547 0.91197606]
#  [0.72120678 0.35662787 0.71277162 0.2219832  0.82947701 0.30903285
#   0.10054436 0.54341952]]
#
# Q=
#  [[ 0.47216507 -0.18478353 -0.13863429 -0.42819119 -0.73508369]
#  [ 0.30136051  0.03474922  0.78494326  0.48199496 -0.24396572]
#  [ 0.36806343  0.04937755 -0.59944545  0.70520927 -0.07373061]
#  [ 0.415704    0.85418657  0.01318978 -0.24540835  0.19275959]
#  [ 0.61478573 -0.48225999  0.07166443 -0.16366977  0.59794668]]
# The norm of column 0 is 1.0
# The norm of column 1 is 1.0
# The norm of column 2 is 1.0
# The norm of column 3 is 1.0000000000000002
# The norm of column 4 is 1.0
# The dot product between columns 0 and 1 is 3.8191578903782576e-17
# The norm of column 0 is 1.0
# The norm of column 1 is 1.0
# The norm of column 2 is 1.0
# The norm of column 3 is 1.0000000000000002
# The norm of column 4 is 1.0
# The dot product between columns 0 and 2 is 7.336399278784738e-17
# The dot product between columns 1 and 2 is -4.2978486586229904e-16
# The norm of column 0 is 1.0
# The norm of column 1 is 1.0
# The norm of column 2 is 1.0
# The norm of column 3 is 1.0000000000000002
# The norm of column 4 is 1.0
# The dot product between columns 0 and 3 is -6.149591191244051e-17
# The dot product between columns 1 and 3 is -2.688225652736951e-16
# The dot product between columns 2 and 3 is 2.3412747541236366e-16
# The norm of column 0 is 1.0
# The norm of column 1 is 1.0
# The norm of column 2 is 1.0
# The norm of column 3 is 1.0000000000000002
# The norm of column 4 is 1.0
# The dot product between columns 0 and 4 is 1.8091169885962618e-16
# The dot product between columns 1 and 4 is -5.855325778728724e-17
# The dot product between columns 2 and 4 is -4.50508805388403e-16
# The dot product between columns 3 and 4 is 2.5644780269545326e-16
# The norm of column 0 is 1.0
# The norm of column 1 is 1.0
# The norm of column 2 is 1.0
# The norm of column 3 is 1.0000000000000002
# The norm of column 4 is 1.0
#
# QQ^T =?= I: True
# Average Absolute Error (QQ^T - I): 2.0822333282606264e-16
# ============================================================
# Test 3
#
# M=
#  [[0.0139342  0.96075424 0.62147565 0.79493836 0.18540914 0.88054444
#   0.91351444 0.64614082]
#  [0.73438453 0.48954523 0.56666389 0.1580926  0.07277256 0.73827203
#   0.39873529 0.21386854]
#  [0.03547897 0.91799359 0.31358586 0.17266815 0.72938272 0.54230956
#   0.32949761 0.68742501]
#  [0.47789923 0.57669109 0.03920939 0.47956496 0.59782905 0.4168564
#   0.67987853 0.5310194 ]
#  [0.06440461 0.4806307  0.76679246 0.79071516 0.5762681  0.15727038
#   0.14671305 0.44777198]]
#
# Q=
#  [[ 0.01584548  0.68528535  0.10879216  0.2010158  -0.69129575]
#  [ 0.83511625 -0.13492894  0.290737   -0.40607959 -0.18693955]
#  [ 0.04034544  0.64003119 -0.31972033 -0.55380709  0.42403884]
#  [ 0.5434502   0.09879901 -0.52402552  0.61449887  0.20661324]
#  [ 0.07323866  0.30459318  0.72581846  0.33223614  0.51445681]]
# The norm of column 0 is 1.0
# The norm of column 1 is 1.0
# The norm of column 2 is 1.0000000000000004
# The norm of column 3 is 0.9999999999999999
# The norm of column 4 is 0.9999999999999997
# The dot product between columns 0 and 1 is -1.07963687841659e-16
# The norm of column 0 is 1.0
# The norm of column 1 is 1.0
# The norm of column 2 is 1.0000000000000004
# The norm of column 3 is 0.9999999999999999
# The norm of column 4 is 0.9999999999999997
# The dot product between columns 0 and 2 is -7.889651609576216e-17
# The dot product between columns 1 and 2 is -3.436220221021133e-17
# The norm of column 0 is 1.0
# The norm of column 1 is 1.0
# The norm of column 2 is 1.0000000000000004
# The norm of column 3 is 0.9999999999999999
# The norm of column 4 is 0.9999999999999997
# The dot product between columns 0 and 3 is 1.737322144353747e-16
# The dot product between columns 1 and 3 is 4.108993128394841e-17
# The dot product between columns 2 and 3 is -6.848089324805206e-16
# The norm of column 0 is 1.0
# The norm of column 1 is 1.0
# The norm of column 2 is 1.0000000000000004
# The norm of column 3 is 0.9999999999999999
# The norm of column 4 is 0.9999999999999997
# The dot product between columns 0 and 4 is 1.040052983909411e-16
# The dot product between columns 1 and 4 is -1.232362947271963e-16
# The dot product between columns 2 and 4 is 4.3883735693679565e-16
# The dot product between columns 3 and 4 is -1.1371322732124678e-17
# The norm of column 0 is 1.0
# The norm of column 1 is 1.0
# The norm of column 2 is 1.0000000000000004
# The norm of column 3 is 0.9999999999999999
# The norm of column 4 is 0.9999999999999997
#
# QQ^T =?= I: True
# Average Absolute Error (QQ^T - I): 2.631174424918232e-16
# ============================================================
# Test 4
#
# M=
#  [[0.05090672 0.08656871 0.76382741 0.79200653 0.36300001 0.53434112
#   0.72848222 0.80777191]
#  [0.1871572  0.45847698 0.32481038 0.90607964 0.18109392 0.792543
#   0.6834459  0.97131797]
#  [0.3295397  0.96214948 0.19886716 0.86767484 0.55296572 0.44859887
#   0.40120556 0.61981966]
#  [0.25001227 0.15375756 0.54062059 0.37636971 0.51503877 0.76288644
#   0.61214899 0.42934016]
#  [0.56429508 0.38600828 0.89884329 0.70780186 0.17864006 0.34678172
#   0.84831769 0.08441264]]
#
# Q=
#  [[ 0.07011447  0.03243382  0.95905185 -0.17400739 -0.20969737]
#  [ 0.257774    0.32143958  0.16792384  0.87827469  0.17511229]
#  [ 0.45387923  0.78933289 -0.13953098 -0.38678055 -0.04334906]
#  [ 0.34434509 -0.23209661  0.13446028 -0.2159701   0.87340424]
#  [ 0.7772108  -0.46766376 -0.12030242  0.04596431 -0.40080992]]
# The norm of column 0 is 1.0
# The norm of column 1 is 0.9999999999999999
# The norm of column 2 is 0.9999999999999996
# The norm of column 3 is 0.9999999999999998
# The norm of column 4 is 1.0000000000000007
# The dot product between columns 0 and 1 is 7.586167852435929e-17
# The norm of column 0 is 1.0
# The norm of column 1 is 0.9999999999999999
# The norm of column 2 is 0.9999999999999996
# The norm of column 3 is 0.9999999999999998
# The norm of column 4 is 1.0000000000000007
# The dot product between columns 0 and 2 is 2.828145267163741e-16
# The dot product between columns 1 and 2 is -2.229191288057872e-16
# The norm of column 0 is 1.0
# The norm of column 1 is 0.9999999999999999
# The norm of column 2 is 0.9999999999999996
# The norm of column 3 is 0.9999999999999998
# The norm of column 4 is 1.0000000000000007
# The dot product between columns 0 and 3 is -9.416754583747736e-16
# The dot product between columns 1 and 3 is 1.7712768060501475e-17
# The dot product between columns 2 and 3 is 1.4862740850833533e-15
# The norm of column 0 is 1.0
# The norm of column 1 is 0.9999999999999999
# The norm of column 2 is 0.9999999999999996
# The norm of column 3 is 0.9999999999999998
# The norm of column 4 is 1.0000000000000007
# The dot product between columns 0 and 4 is -7.364645835922194e-16
# The dot product between columns 1 and 4 is -1.244350168933166e-17
# The dot product between columns 2 and 4 is 1.4458462597659137e-15
# The dot product between columns 3 and 4 is -1.2191715777528624e-16
# The norm of column 0 is 1.0
# The norm of column 1 is 0.9999999999999999
# The norm of column 2 is 0.9999999999999996
# The norm of column 3 is 0.9999999999999998
# The norm of column 4 is 1.0000000000000007
#
# QQ^T =?= I: True
# Average Absolute Error (QQ^T - I): 6.513066872990298e-16
# ============================================================
# Test 5
#
# M=
#  [[0.11640111 0.76408797 0.15996702 0.63667924 0.71128549 0.12118786
#   0.35639691 0.46567223]
#  [0.26628309 0.9393959  0.04207964 0.00774831 0.6729193  0.08050102
#   0.14575813 0.24670129]
#  [0.09863339 0.24144777 0.88211418 0.91326516 0.84265477 0.20608172
#   0.49595223 0.27687037]
#  [0.1164131  0.30754206 0.73726517 0.83491198 0.87283749 0.26746326
#   0.12148867 0.88802624]
#  [0.19013967 0.77405924 0.32881783 0.06922168 0.76521435 0.60847048
#   0.22381462 0.70773325]]
#
# Q=
#  [[ 0.30686157  0.83998404  0.30300841  0.32781676 -0.03138266]
#  [ 0.70198681 -0.18445688 -0.57655455  0.33165882 -0.17543502]
#  [ 0.26002153 -0.34575387  0.62581365  0.00196171 -0.64899653]
#  [ 0.30689317 -0.34929007  0.42763119  0.28160431  0.72224899]
#  [ 0.5012543   0.13730689  0.03549084 -0.83859034  0.1593662 ]]
# The norm of column 0 is 1.0
# The norm of column 1 is 1.0000000000000024
# The norm of column 2 is 1.0000000000000009
# The norm of column 3 is 1.000000000000004
# The norm of column 4 is 0.999999999999958
# The dot product between columns 0 and 1 is -1.1606635841129249e-15
# The norm of column 0 is 1.0
# The norm of column 1 is 1.0000000000000024
# The norm of column 2 is 1.0000000000000009
# The norm of column 3 is 1.000000000000004
# The norm of column 4 is 0.999999999999958
# The dot product between columns 0 and 2 is -7.566575016263902e-16
# The dot product between columns 1 and 2 is 3.0478242153548793e-15
# The norm of column 0 is 1.0
# The norm of column 1 is 1.0000000000000024
# The norm of column 2 is 1.0000000000000009
# The norm of column 3 is 1.000000000000004
# The norm of column 4 is 0.999999999999958
# The dot product between columns 0 and 3 is 1.5754175067691692e-15
# The dot product between columns 1 and 3 is -5.894318034302838e-15
# The dot product between columns 2 and 3 is -4.175573201727859e-15
# The norm of column 0 is 1.0
# The norm of column 1 is 1.0000000000000024
# The norm of column 2 is 1.0000000000000009
# The norm of column 3 is 1.000000000000004
# The norm of column 4 is 0.999999999999958
# The dot product between columns 0 and 4 is 2.8368994718216133e-15
# The dot product between columns 1 and 4 is -2.0164246983574966e-15
# The dot product between columns 2 and 4 is -7.054965738932945e-16
# The dot product between columns 3 and 4 is 1.9914656075800445e-15
# The norm of column 0 is 1.0
# The norm of column 1 is 1.0000000000000024
# The norm of column 2 is 1.0000000000000009
# The norm of column 3 is 1.000000000000004
# The norm of column 4 is 0.999999999999958
#
# QQ^T =?= I: True
# Average Absolute Error (QQ^T - I): 1.1372456444040292e-14
