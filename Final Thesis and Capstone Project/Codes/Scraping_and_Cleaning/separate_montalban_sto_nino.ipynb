# %%
import pandas as pd
import os

# %%
BASE_DIR_PATH = '/Users/neilb/Documents/dsci_thesis/Datasets'
DATASET_FILE = os.path.join(BASE_DIR_PATH, 'compiled_data_2016_2017.csv')

# %%
df = pd.read_csv(DATASET_FILE)
df
# Out:
#        Unnamed: 0  index  Rainfall_Aries  Rainfall_Boso  Rainfall_Campana  \
# 0               0      0               0              1                 2
# 1               1      1               0              1                 1
# 2               2      2               1              1                 1
# 3               3      3               0              0                 0
# 4               4      4               1              1                 1
# ...           ...    ...             ...            ...               ...
# 17515       17515  16059               0              0                 0
# 17516       17516  16424               0              0                 0
# 17517       17517  16789               0              0                 0
# 17518       17518  17154               0              0                 0
# 17519       17519  17519               0              0                 0
#
#        Rainfall_Nangka  Rainfall_Oro  Waterlevel_Sto_Nino  \
# ...

# %%
df = df.iloc[:,2:]
df
# Out:
#        Rainfall_Aries  Rainfall_Boso  Rainfall_Campana  Rainfall_Nangka  \
# 0                   0              1                 2                0
# 1                   0              1                 1                1
# 2                   1              1                 1                0
# 3                   0              0                 0                1
# 4                   1              1                 1                0
# ...               ...            ...               ...              ...
# 17515               0              0                 0                0
# 17516               0              0                 0                0
# 17517               0              0                 0                0
# 17518               0              0                 0                0
# 17519               0              0                 0                0
#
#        Rainfall_Oro  Waterlevel_Sto_Nino  Waterlevel_Montalban  \
# ...

# %%
df_Sto_Nino = df[['datetime', 'x', 't', 'Rainfall_Aries', 'Rainfall_Boso', 'Rainfall_Campana', 'Rainfall_Nangka', 'Rainfall_Oro', 'Waterlevel_Sto_Nino', 'Discharge_Sto_Nino', 'Cross_Section_Sto_Nino', 'Velocity_Sto_Nino']]
df_Sto_Nino.head()
# Out:
#               datetime      x        t  Rainfall_Aries  Rainfall_Boso  \
# 0  2016-01-01 00:00:00  14420      0.0               0              1
# 1  2016-01-01 01:00:00  14420   3600.0               0              1
# 2  2016-01-01 02:00:00  14420   7200.0               1              1
# 3  2016-01-01 03:00:00  14420  10800.0               0              0
# 4  2016-01-01 04:00:00  14420  14400.0               1              1
#
#    Rainfall_Campana  Rainfall_Nangka  Rainfall_Oro  Waterlevel_Sto_Nino  \
# 0                 2                0             0                12.18
# 1                 1                1             0                12.19
# 2                 1                0             1                12.19
# 3                 0                1             0                12.20
# 4                 1                0             0                12.20
#
#    Discharge_Sto_Nino  Cross_Section_Sto_Nino  Velocity_Sto_Nino
# ...

# %%
df_Sto_Nino = df_Sto_Nino.rename(columns={
    'Waterlevel_Sto_Nino': 'Waterlevel', 
    'Discharge_Sto_Nino': 'Discharge', 
    'Cross_Section_Sto_Nino': 'Cross_Section', 
    'Velocity_Sto_Nino': 'Velocity'
})
df_Sto_Nino
# Out:
#                   datetime      x           t  Rainfall_Aries  Rainfall_Boso  \
# 0      2016-01-01 00:00:00  14420         0.0               0              1
# 1      2016-01-01 01:00:00  14420      3600.0               0              1
# 2      2016-01-01 02:00:00  14420      7200.0               1              1
# 3      2016-01-01 03:00:00  14420     10800.0               0              0
# 4      2016-01-01 04:00:00  14420     14400.0               1              1
# ...                    ...    ...         ...             ...            ...
# 17515  2017-12-31 19:00:00  14420  63140400.0               0              0
# 17516  2017-12-31 20:00:00  14420  63144000.0               0              0
# 17517  2017-12-31 21:00:00  14420  63147600.0               0              0
# 17518  2017-12-31 22:00:00  14420  63151200.0               0              0
# 17519  2017-12-31 23:00:00  14420  63154800.0               0              0
#
# ...

# %%
df_Sto_Nino['Station'] = ['Sto_Nino' for x in range(len(df_Sto_Nino))]
df_Sto_Nino['fric_coeff'] = [0.033 for x in range(len(df_Sto_Nino))]
df_Sto_Nino['slope'] = [1/1500 for x in range(len(df_Sto_Nino))]
df_Sto_Nino
# Out:
#                   datetime      x           t  Rainfall_Aries  Rainfall_Boso  \
# 0      2016-01-01 00:00:00  14420         0.0               0              1
# 1      2016-01-01 01:00:00  14420      3600.0               0              1
# 2      2016-01-01 02:00:00  14420      7200.0               1              1
# 3      2016-01-01 03:00:00  14420     10800.0               0              0
# 4      2016-01-01 04:00:00  14420     14400.0               1              1
# ...                    ...    ...         ...             ...            ...
# 17515  2017-12-31 19:00:00  14420  63140400.0               0              0
# 17516  2017-12-31 20:00:00  14420  63144000.0               0              0
# 17517  2017-12-31 21:00:00  14420  63147600.0               0              0
# 17518  2017-12-31 22:00:00  14420  63151200.0               0              0
# 17519  2017-12-31 23:00:00  14420  63154800.0               0              0
#
# ...

# %%
df_Montalban = df[['datetime', 'x', 't', 'Rainfall_Aries', 'Rainfall_Boso', 'Rainfall_Campana', 'Rainfall_Nangka', 'Rainfall_Oro', 'Waterlevel_Montalban', 'Discharge_San_Jose', 'Cross_Section_Montalban', 'Velocity_Montalban']]
df_Montalban.head()
# Out:
#               datetime      x        t  Rainfall_Aries  Rainfall_Boso  \
# 0  2016-01-01 00:00:00  14420      0.0               0              1
# 1  2016-01-01 01:00:00  14420   3600.0               0              1
# 2  2016-01-01 02:00:00  14420   7200.0               1              1
# 3  2016-01-01 03:00:00  14420  10800.0               0              0
# 4  2016-01-01 04:00:00  14420  14400.0               1              1
#
#    Rainfall_Campana  Rainfall_Nangka  Rainfall_Oro  Waterlevel_Montalban  \
# 0                 2                0             0                 21.03
# 1                 1                1             0                 21.03
# 2                 1                0             1                 21.03
# 3                 0                1             0                 21.03
# 4                 1                0             0                 21.03
#
#    Discharge_San_Jose  Cross_Section_Montalban  Velocity_Montalban
# ...

# %%
df_Montalban = df_Montalban.rename(columns={
    'Waterlevel_Montalban': 'Waterlevel', 
    'Discharge_San_Jose': 'Discharge', 
    'Cross_Section_Montalban': 'Cross_Section', 
    'Velocity_Montalban': 'Velocity'
})
df_Montalban
# Out:
#                   datetime      x           t  Rainfall_Aries  Rainfall_Boso  \
# 0      2016-01-01 00:00:00  14420         0.0               0              1
# 1      2016-01-01 01:00:00  14420      3600.0               0              1
# 2      2016-01-01 02:00:00  14420      7200.0               1              1
# 3      2016-01-01 03:00:00  14420     10800.0               0              0
# 4      2016-01-01 04:00:00  14420     14400.0               1              1
# ...                    ...    ...         ...             ...            ...
# 17515  2017-12-31 19:00:00  14420  63140400.0               0              0
# 17516  2017-12-31 20:00:00  14420  63144000.0               0              0
# 17517  2017-12-31 21:00:00  14420  63147600.0               0              0
# 17518  2017-12-31 22:00:00  14420  63151200.0               0              0
# 17519  2017-12-31 23:00:00  14420  63154800.0               0              0
#
# ...

# %%
df_Montalban['Station'] = ['Montalban' for x in range(len(df_Sto_Nino))]
df_Montalban['fric_coeff'] = [0.035 for x in range(len(df_Sto_Nino))]
df_Montalban['slope'] = [0.002 for x in range(len(df_Sto_Nino))]
df_Montalban['x'] = [0 for x in range(len(df_Montalban))]
df_Montalban
# Out:
#                   datetime  x           t  Rainfall_Aries  Rainfall_Boso  \
# 0      2016-01-01 00:00:00  0         0.0               0              1
# 1      2016-01-01 01:00:00  0      3600.0               0              1
# 2      2016-01-01 02:00:00  0      7200.0               1              1
# 3      2016-01-01 03:00:00  0     10800.0               0              0
# 4      2016-01-01 04:00:00  0     14400.0               1              1
# ...                    ... ..         ...             ...            ...
# 17515  2017-12-31 19:00:00  0  63140400.0               0              0
# 17516  2017-12-31 20:00:00  0  63144000.0               0              0
# 17517  2017-12-31 21:00:00  0  63147600.0               0              0
# 17518  2017-12-31 22:00:00  0  63151200.0               0              0
# 17519  2017-12-31 23:00:00  0  63154800.0               0              0
#
#        Rainfall_Campana  Rainfall_Nangka  Rainfall_Oro  Waterlevel  Discharge  \
# ...

# %%
final_df = pd.concat([df_Sto_Nino, df_Montalban], axis=0)
final_df
# Out:
#                   datetime      x           t  Rainfall_Aries  Rainfall_Boso  \
# 0      2016-01-01 00:00:00  14420         0.0               0              1
# 1      2016-01-01 01:00:00  14420      3600.0               0              1
# 2      2016-01-01 02:00:00  14420      7200.0               1              1
# 3      2016-01-01 03:00:00  14420     10800.0               0              0
# 4      2016-01-01 04:00:00  14420     14400.0               1              1
# ...                    ...    ...         ...             ...            ...
# 17515  2017-12-31 19:00:00      0  63140400.0               0              0
# 17516  2017-12-31 20:00:00      0  63144000.0               0              0
# 17517  2017-12-31 21:00:00      0  63147600.0               0              0
# 17518  2017-12-31 22:00:00      0  63151200.0               0              0
# 17519  2017-12-31 23:00:00      0  63154800.0               0              0
#
# ...

# %%
final_df = final_df[['datetime', 'Station', 'x', 't', 'Rainfall_Aries', 'Rainfall_Boso', 'Rainfall_Campana', 'Rainfall_Nangka', 'Rainfall_Oro', 'Waterlevel', 'Discharge', 'Cross_Section', 'Velocity', 'fric_coeff', 'slope']]
final_df.sort_values(['datetime', 'Station'], inplace=True)
final_df.reset_index(drop=True, inplace=True)
final_df
# Out:
#                   datetime    Station      x           t  Rainfall_Aries  \
# 0      2016-01-01 00:00:00  Montalban      0         0.0               0
# 1      2016-01-01 00:00:00   Sto_Nino  14420         0.0               0
# 2      2016-01-01 01:00:00  Montalban      0      3600.0               0
# 3      2016-01-01 01:00:00   Sto_Nino  14420      3600.0               0
# 4      2016-01-01 02:00:00  Montalban      0      7200.0               1
# ...                    ...        ...    ...         ...             ...
# 35035  2017-12-31 21:00:00   Sto_Nino  14420  63147600.0               0
# 35036  2017-12-31 22:00:00  Montalban      0  63151200.0               0
# 35037  2017-12-31 22:00:00   Sto_Nino  14420  63151200.0               0
# 35038  2017-12-31 23:00:00  Montalban      0  63154800.0               0
# 35039  2017-12-31 23:00:00   Sto_Nino  14420  63154800.0               0
#
#        Rainfall_Boso  Rainfall_Campana  Rainfall_Nangka  Rainfall_Oro  \
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35040 entries, 0 to 35039
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   datetime          35040 non-null  object
#  1   Station           35040 non-null  object
#  2   x                 35040 non-null  int64
#  3   t                 35040 non-null  float64
#  4   Rainfall_Aries    35040 non-null  int64
#  5   Rainfall_Boso     35040 non-null  int64
#  6   Rainfall_Campana  35040 non-null  int64
#  7   Rainfall_Nangka   35040 non-null  int64
#  8   Rainfall_Oro      35040 non-null  int64
#  9   Waterlevel        35040 non-null  float64
#  10  Discharge         35040 non-null  float64
#  11  Cross_Section     35040 non-null  float64
#  12  Velocity          35040 non-null  float64
#  13  fric_coeff        35040 non-null  float64
#  14  slope             35040 non-null  float64
# dtypes: float64(7), int64(6), object(2)
# memory usage: 4.0+ MB

# %%
final_df['datetime'] = pd.to_datetime(final_df['datetime'])
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35040 entries, 0 to 35039
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   datetime          35040 non-null  datetime64[ns]
#  1   Station           35040 non-null  object
#  2   x                 35040 non-null  int64
#  3   t                 35040 non-null  float64
#  4   Rainfall_Aries    35040 non-null  int64
#  5   Rainfall_Boso     35040 non-null  int64
#  6   Rainfall_Campana  35040 non-null  int64
#  7   Rainfall_Nangka   35040 non-null  int64
#  8   Rainfall_Oro      35040 non-null  int64
#  9   Waterlevel        35040 non-null  float64
#  10  Discharge         35040 non-null  float64
#  11  Cross_Section     35040 non-null  float64
#  12  Velocity          35040 non-null  float64
#  13  fric_coeff        35040 non-null  float64
#  14  slope             35040 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int64(6), object(1)
# ...

# %%
import datetime as dt

# %%
final_df['month'] = [x.month for x in final_df['datetime']]

# %%
final_df
# Out:
#                  datetime    Station      x           t  Rainfall_Aries  \
# 0     2016-01-01 00:00:00  Montalban      0         0.0               0
# 1     2016-01-01 00:00:00   Sto_Nino  14420         0.0               0
# 2     2016-01-01 01:00:00  Montalban      0      3600.0               0
# 3     2016-01-01 01:00:00   Sto_Nino  14420      3600.0               0
# 4     2016-01-01 02:00:00  Montalban      0      7200.0               1
# ...                   ...        ...    ...         ...             ...
# 35035 2017-12-31 21:00:00   Sto_Nino  14420  63147600.0               0
# 35036 2017-12-31 22:00:00  Montalban      0  63151200.0               0
# 35037 2017-12-31 22:00:00   Sto_Nino  14420  63151200.0               0
# 35038 2017-12-31 23:00:00  Montalban      0  63154800.0               0
# 35039 2017-12-31 23:00:00   Sto_Nino  14420  63154800.0               0
#
#        Rainfall_Boso  Rainfall_Campana  Rainfall_Nangka  Rainfall_Oro  \
# ...

# %%
final_df['day'] = [x.day for x in final_df['datetime']]
final_df
# Out:
#                  datetime    Station      x           t  Rainfall_Aries  \
# 0     2016-01-01 00:00:00  Montalban      0         0.0               0
# 1     2016-01-01 00:00:00   Sto_Nino  14420         0.0               0
# 2     2016-01-01 01:00:00  Montalban      0      3600.0               0
# 3     2016-01-01 01:00:00   Sto_Nino  14420      3600.0               0
# 4     2016-01-01 02:00:00  Montalban      0      7200.0               1
# ...                   ...        ...    ...         ...             ...
# 35035 2017-12-31 21:00:00   Sto_Nino  14420  63147600.0               0
# 35036 2017-12-31 22:00:00  Montalban      0  63151200.0               0
# 35037 2017-12-31 22:00:00   Sto_Nino  14420  63151200.0               0
# 35038 2017-12-31 23:00:00  Montalban      0  63154800.0               0
# 35039 2017-12-31 23:00:00   Sto_Nino  14420  63154800.0               0
#
#        Rainfall_Boso  Rainfall_Campana  Rainfall_Nangka  Rainfall_Oro  \
# ...

# %%
final_df['hour'] = [x.hour for x in final_df['datetime']]
final_df
# Out:
#                  datetime    Station      x           t  Rainfall_Aries  \
# 0     2016-01-01 00:00:00  Montalban      0         0.0               0
# 1     2016-01-01 00:00:00   Sto_Nino  14420         0.0               0
# 2     2016-01-01 01:00:00  Montalban      0      3600.0               0
# 3     2016-01-01 01:00:00   Sto_Nino  14420      3600.0               0
# 4     2016-01-01 02:00:00  Montalban      0      7200.0               1
# ...                   ...        ...    ...         ...             ...
# 35035 2017-12-31 21:00:00   Sto_Nino  14420  63147600.0               0
# 35036 2017-12-31 22:00:00  Montalban      0  63151200.0               0
# 35037 2017-12-31 22:00:00   Sto_Nino  14420  63151200.0               0
# 35038 2017-12-31 23:00:00  Montalban      0  63154800.0               0
# 35039 2017-12-31 23:00:00   Sto_Nino  14420  63154800.0               0
#
#        Rainfall_Boso  Rainfall_Campana  Rainfall_Nangka  Rainfall_Oro  \
# ...

# %%
final_df = final_df[['datetime', 'month', 'day', 'hour', 't', 'Station', 'x', 'Rainfall_Aries', 'Rainfall_Boso', 'Rainfall_Campana', 'Rainfall_Nangka', 'Rainfall_Oro', 'Waterlevel', 'Discharge', 'Cross_Section', 'Velocity', 'fric_coeff', 'slope']]
final_df
# Out:
#                  datetime  month  day  hour           t    Station      x  \
# 0     2016-01-01 00:00:00      1    1     0         0.0  Montalban      0
# 1     2016-01-01 00:00:00      1    1     0         0.0   Sto_Nino  14420
# 2     2016-01-01 01:00:00      1    1     1      3600.0  Montalban      0
# 3     2016-01-01 01:00:00      1    1     1      3600.0   Sto_Nino  14420
# 4     2016-01-01 02:00:00      1    1     2      7200.0  Montalban      0
# ...                   ...    ...  ...   ...         ...        ...    ...
# 35035 2017-12-31 21:00:00     12   31    21  63147600.0   Sto_Nino  14420
# 35036 2017-12-31 22:00:00     12   31    22  63151200.0  Montalban      0
# 35037 2017-12-31 22:00:00     12   31    22  63151200.0   Sto_Nino  14420
# 35038 2017-12-31 23:00:00     12   31    23  63154800.0  Montalban      0
# 35039 2017-12-31 23:00:00     12   31    23  63154800.0   Sto_Nino  14420
#
#        Rainfall_Aries  Rainfall_Boso  Rainfall_Campana  Rainfall_Nangka  \
# ...

# %%
final_df.to_csv('../Datasets/2016_2017_sto_nino_and_montalban.csv')
