# %% [markdown]
# results 4.3.2

# %%
import tensorflow as tf
import pandas as pd
import os
import numpy as np
import datetime as dt
from random import seed
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import backend as K
tf.compat.v1.experimental.output_all_intermediates(True)

# %%
tf.random.set_seed(36)

# %% [markdown]
# ## Dataset

# %%
BASE_DIR_PATH = '/Users/neilb/Documents/dsci_thesis/Datasets'
DATASET_FILE = os.path.join(BASE_DIR_PATH, 'compiled_data_2016_2017.csv')

# %%
df = pd.read_csv(DATASET_FILE)
df
# Out:
#        Unnamed: 0  index  Rainfall_Aries  Rainfall_Boso  Rainfall_Campana  \
# 0               0      0               0              1                 2
# 1               1      1               0              1                 1
# 2               2      2               1              1                 1
# 3               3      3               0              0                 0
# 4               4      4               1              1                 1
# ...           ...    ...             ...            ...               ...
# 17515       17515  16059               0              0                 0
# 17516       17516  16424               0              0                 0
# 17517       17517  16789               0              0                 0
# 17518       17518  17154               0              0                 0
# 17519       17519  17519               0              0                 0
#
#        Rainfall_Nangka  Rainfall_Oro  Waterlevel_Sto_Nino  \
# 0                    0             0                12.18
# 1                    1             0                12.19
# 2                    0             1                12.19
# 3                    1             0                12.20
# 4                    0             0                12.20
# ...                ...           ...                  ...
# 17515                0             0                12.44
# 17516                0             0                12.44
# 17517                0             0                12.44
# 17518                0             0                12.44
# 17519                0             0                12.44
#
#        Waterlevel_Montalban  Discharge_Sto_Nino  Discharge_San_Jose  \
# 0                     21.03           21.033407           14.842428
# 1                     21.03           21.280072           14.842428
# 2                     21.03           21.280072           14.842428
# 3                     21.03           21.529056           14.842428
# 4                     21.03           21.529056           14.842428
# ...                     ...                 ...                 ...
# 17515                 21.18           28.244204           17.224575
# 17516                 21.18           28.244204           17.224575
# 17517                 21.18           28.244204           17.224575
# 17518                 21.18           28.244204           17.224575
# 17519                 21.18           28.244204           17.224575
#
#        Cross_Section_Sto_Nino  Cross_Section_Montalban  Velocity_Sto_Nino  \
# 0                      803.88                    630.9           0.026165
# 1                      804.54                    630.9           0.026450
# 2                      804.54                    630.9           0.026450
# 3                      805.20                    630.9           0.026738
# 4                      805.20                    630.9           0.026738
# ...                       ...                      ...                ...
# 17515                  821.04                    635.4           0.034401
# 17516                  821.04                    635.4           0.034401
# 17517                  821.04                    635.4           0.034401
# 17518                  821.04                    635.4           0.034401
# 17519                  821.04                    635.4           0.034401
#
#        Velocity_Montalban             datetime           t      x
# 0                0.023526  2016-01-01 00:00:00         0.0  14420
# 1                0.023526  2016-01-01 01:00:00      3600.0  14420
# 2                0.023526  2016-01-01 02:00:00      7200.0  14420
# 3                0.023526  2016-01-01 03:00:00     10800.0  14420
# 4                0.023526  2016-01-01 04:00:00     14400.0  14420
# ...                   ...                  ...         ...    ...
# 17515            0.027108  2017-12-31 19:00:00  63140400.0  14420
# 17516            0.027108  2017-12-31 20:00:00  63144000.0  14420
# 17517            0.027108  2017-12-31 21:00:00  63147600.0  14420
# 17518            0.027108  2017-12-31 22:00:00  63151200.0  14420
# 17519            0.027108  2017-12-31 23:00:00  63154800.0  14420
#
# [17520 rows x 18 columns]

# %%
df = df[['x', 't', 'Discharge_Sto_Nino', 'Waterlevel_Sto_Nino', 'Velocity_Sto_Nino']]
df.head()
# Out:
#        x        t  Discharge_Sto_Nino  Waterlevel_Sto_Nino  Velocity_Sto_Nino
# 0  14420      0.0           21.033407                12.18           0.026165
# 1  14420   3600.0           21.280072                12.19           0.026450
# 2  14420   7200.0           21.280072                12.19           0.026450
# 3  14420  10800.0           21.529056                12.20           0.026738
# 4  14420  14400.0           21.529056                12.20           0.026738

# %%
n = len(df)

# %%
df['friction_coeff'] = [0.033 for i in range(n)]
df['slope'] = [1/1500 for i in range(n)]
df.head()
# Out:
# C:\Users\neilb\AppData\Local\Temp\ipykernel_43272\1076625494.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['friction_coeff'] = [0.033 for i in range(n)]
# C:\Users\neilb\AppData\Local\Temp\ipykernel_43272\1076625494.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['slope'] = [1/1500 for i in range(n)]
#        x        t  Discharge_Sto_Nino  Waterlevel_Sto_Nino  Velocity_Sto_Nino  \
# 0  14420      0.0           21.033407                12.18           0.026165
# 1  14420   3600.0           21.280072                12.19           0.026450
# 2  14420   7200.0           21.280072                12.19           0.026450
# 3  14420  10800.0           21.529056                12.20           0.026738
# 4  14420  14400.0           21.529056                12.20           0.026738
#
#    friction_coeff     slope
# 0           0.033  0.000667
# 1           0.033  0.000667
# 2           0.033  0.000667
# 3           0.033  0.000667
# 4           0.033  0.000667

# %%
# Splitting for time series: split into 50-25-25
train_df = df[0:int(n*0.5)]
val_df = df[int(n*0.5):int(n*0.75)]
test_df = df[int(n*0.75):]

# %% [markdown]
# ## Window Generator

# %%
class WindowGenerator():
    def __init__(self, input_width, label_width, shift, train_df=train_df, val_df=val_df, test_df=test_df, label_columns=None):
        # Store the raw data.
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df

        # Work out the label column indices.
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}

        # Work out the window parameters.
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift

        self.total_window_size = input_width + shift

        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]

        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]

    def __repr__(self):
        return '\n'.join([
            f'Total window size: {self.total_window_size}',
            f'Input indices: {self.input_indices}',
            f'Label indices: {self.label_indices}',
            f'Label column name(s): {self.label_columns}'])

    def split_window(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack([labels[:, :, self.column_indices[name]] for name in self.label_columns], axis=-1)

        # Slicing doesn't preserve static shape information, so set the shapes
        # manually. This way the `tf.data.Datasets` are easier to inspect.
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])

        return inputs, labels
    
    # Creating tf datasets for more convenient use and integration into model in the future
    def make_dataset(self, data, shuffle=True):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.utils.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=shuffle,
            batch_size=32,)

        ds = ds.map(self.split_window)

        return ds
    
    # properties to access them as tf datasets
    @property
    def train(self):
        return self.make_dataset(self.train_df)

    @property
    def val(self):
        return self.make_dataset(self.val_df)

    @property
    def test(self):
        return self.make_dataset(self.test_df, False)

    @property
    def example(self):
        """Get and cache an example batch of `inputs, labels` for plotting."""
        result = getattr(self, '_example', None)
        if result is None:
            # No example batch was found, so get one from the `.train` dataset
            result = next(iter(self.train))
            # And cache it for next time
            self._example = result
        return result

# %%
# The wide window uses independent hours of data as input to predict the water level of the next hour
# Here, the prediction is done on 6 hours
# This is used for Dense and Recurrent Neural Networks
wide_window = WindowGenerator(
        input_width=6, label_width=6, shift=1,
        label_columns=['Waterlevel_Sto_Nino', 'Velocity_Sto_Nino']
    )

wide_window
# Out:
# Total window size: 7
# Input indices: [0 1 2 3 4 5]
# Label indices: [1 2 3 4 5 6]
# Label column name(s): ['Waterlevel_Sto_Nino', 'Velocity_Sto_Nino']

# %%
for example_inputs, example_labels in wide_window.train.take(1):
    print(f'Inputs shape (batch, time, features): {example_inputs.shape}')
    print(f'Labels shape (batch, time, features): {example_labels.shape}')
# Out:
# Inputs shape (batch, time, features): (32, 6, 7)
# Labels shape (batch, time, features): (32, 6, 2)

# %%
wide_window.example
# Out:
# (<tf.Tensor: shape=(32, 6, 7), dtype=float32, numpy=
#  array([[[1.4420000e+04, 1.4756400e+07, 1.7389021e+01, ...,
#           2.1919303e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 1.4760000e+07, 1.7389021e+01, ...,
#           2.1919303e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 1.4763600e+07, 1.7389021e+01, ...,
#           2.1919303e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 1.4767200e+07, 1.7389021e+01, ...,
#           2.1919303e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 1.4770800e+07, 1.7389021e+01, ...,
#           2.1919303e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 1.4774400e+07, 1.7389021e+01, ...,
#           2.1919303e-02, 3.3000000e-02, 6.6666666e-04]],
#
#         [[1.4420000e+04, 2.7514800e+07, 3.0161154e+01, ...,
#           3.6558975e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 2.7518400e+07, 3.0161154e+01, ...,
#           3.6558975e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 2.7522000e+07, 3.0161154e+01, ...,
#           3.6558975e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 2.7525600e+07, 3.0161154e+01, ...,
#           3.6558975e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 2.7529200e+07, 3.0161154e+01, ...,
#           3.6558975e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 2.7532800e+07, 3.0161154e+01, ...,
#           3.6558975e-02, 3.3000000e-02, 6.6666666e-04]],
#
#         [[1.4420000e+04, 2.7684000e+07, 4.5783386e+01, ...,
#           5.3774238e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 2.7687600e+07, 4.5783386e+01, ...,
#           5.3774238e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 2.7691200e+07, 4.5783386e+01, ...,
#           5.3774238e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 2.7694800e+07, 4.5783386e+01, ...,
#           5.3774238e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 2.7698400e+07, 4.5783386e+01, ...,
#           5.3774238e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 2.7702000e+07, 4.5783386e+01, ...,
#           5.3774238e-02, 3.3000000e-02, 6.6666666e-04]],
#
#         ...,
#
#         [[1.4420000e+04, 2.7090000e+07, 3.8104435e+01, ...,
#           4.5388356e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 2.7093600e+07, 3.8104435e+01, ...,
#           4.5388356e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 2.7097200e+07, 3.7710339e+01, ...,
#           4.4954270e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 2.7100800e+07, 3.7710339e+01, ...,
#           4.4954270e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 2.7104400e+07, 3.7710339e+01, ...,
#           4.4954270e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 2.7108000e+07, 3.7710339e+01, ...,
#           4.4954270e-02, 3.3000000e-02, 6.6666666e-04]],
#
#         [[1.4420000e+04, 7.4880000e+06, 1.4450867e+01, ...,
#           1.8445874e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 7.4916000e+06, 1.4450867e+01, ...,
#           1.8445874e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 7.4952000e+06, 1.4450867e+01, ...,
#           1.8445874e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 7.4988000e+06, 1.4450867e+01, ...,
#           1.8445874e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 7.5024000e+06, 1.4450867e+01, ...,
#           1.8445874e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 7.5060000e+06, 1.4450867e+01, ...,
#           1.8445874e-02, 3.3000000e-02, 6.6666666e-04]],
#
#         [[1.4420000e+04, 9.1188000e+06, 1.4450867e+01, ...,
#           1.8445874e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 9.1224000e+06, 1.4450867e+01, ...,
#           1.8445874e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 9.1260000e+06, 1.4450867e+01, ...,
#           1.8445874e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 9.1296000e+06, 1.4450867e+01, ...,
#           1.8445874e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 9.1332000e+06, 1.4450867e+01, ...,
#           1.8445874e-02, 3.3000000e-02, 6.6666666e-04],
#          [1.4420000e+04, 9.1368000e+06, 1.4450867e+01, ...,
#           1.8445874e-02, 3.3000000e-02, 6.6666666e-04]]], dtype=float32)>,
#  <tf.Tensor: shape=(32, 6, 2), dtype=float32, numpy=
#  array([[[1.2020000e+01, 2.1919303e-02],
#          [1.2020000e+01, 2.1919303e-02],
#          [1.2020000e+01, 2.1919303e-02],
#          [1.2020000e+01, 2.1919303e-02],
#          [1.2020000e+01, 2.1919303e-02],
#          [1.2020000e+01, 2.1919303e-02]],
#
#         [[1.2500000e+01, 3.6558975e-02],
#          [1.2500000e+01, 3.6558975e-02],
#          [1.2500000e+01, 3.6558975e-02],
#          [1.2500000e+01, 3.6558975e-02],
#          [1.2500000e+01, 3.6558975e-02],
#          [1.2490000e+01, 3.6192115e-02]],
#
#         [[1.2900000e+01, 5.3774238e-02],
#          [1.2900000e+01, 5.3774238e-02],
#          [1.2900000e+01, 5.3774238e-02],
#          [1.2900000e+01, 5.3774238e-02],
#          [1.2900000e+01, 5.3774238e-02],
#          [1.2890000e+01, 5.3279012e-02]],
#
#         [[1.1870000e+01, 1.8445874e-02],
#          [1.1870000e+01, 1.8445874e-02],
#          [1.1870000e+01, 1.8445874e-02],
#          [1.1870000e+01, 1.8445874e-02],
#          [1.1870000e+01, 1.8445874e-02],
#          [1.1870000e+01, 1.8445874e-02]],
#
#         [[1.1310000e+01, 9.0773664e-03],
#          [1.1310000e+01, 9.0773664e-03],
#          [1.1310000e+01, 9.0773664e-03],
#          [1.1310000e+01, 9.0773664e-03],
#          [1.1310000e+01, 9.0773664e-03],
#          [1.1310000e+01, 9.0773664e-03]],
#
#         [[1.3070000e+01, 6.2753484e-02],
#          [1.3060000e+01, 6.2195152e-02],
#          [1.3050000e+01, 6.1640680e-02],
#          [1.3050000e+01, 6.1640680e-02],
#          [1.3040000e+01, 6.1090052e-02],
#          [1.3030000e+01, 6.0543247e-02]],
#
#         [[1.1960000e+01, 2.0473758e-02],
#          [1.1960000e+01, 2.0473758e-02],
#          [1.1960000e+01, 2.0473758e-02],
#          [1.1960000e+01, 2.0473758e-02],
#          [1.1960000e+01, 2.0473758e-02],
#          [1.1960000e+01, 2.0473758e-02]],
#
#         [[1.2640000e+01, 4.2005181e-02],
#          [1.2680000e+01, 4.3671329e-02],
#          [1.2690000e+01, 4.4095773e-02],
#          [1.2690000e+01, 4.4095773e-02],
#          [1.2660000e+01, 4.2831961e-02],
#          [1.2620000e+01, 4.1190855e-02]],
#
#         [[1.1870000e+01, 1.8445874e-02],
#          [1.1870000e+01, 1.8445874e-02],
#          [1.1870000e+01, 1.8445874e-02],
#          [1.1870000e+01, 1.8445874e-02],
#          [1.1870000e+01, 1.8445874e-02],
#          [1.1870000e+01, 1.8445874e-02]],
#
#         [[1.1880000e+01, 1.8663118e-02],
#          [1.1880000e+01, 1.8663118e-02],
#          [1.1880000e+01, 1.8663118e-02],
#          [1.1880000e+01, 1.8663118e-02],
#          [1.1880000e+01, 1.8663118e-02],
#          [1.1880000e+01, 1.8663118e-02]],
#
#         [[1.2240000e+01, 2.7912097e-02],
#          [1.2240000e+01, 2.7912097e-02],
#          [1.2240000e+01, 2.7912097e-02],
#          [1.2240000e+01, 2.7912097e-02],
#          [1.2240000e+01, 2.7912097e-02],
#          [1.2240000e+01, 2.7912097e-02]],
#
#         [[1.1340000e+01, 9.4564585e-03],
#          [1.1340000e+01, 9.4564585e-03],
#          [1.1340000e+01, 9.4564585e-03],
#          [1.1340000e+01, 9.4564585e-03],
#          [1.1340000e+01, 9.4564585e-03],
#          [1.1340000e+01, 9.4564585e-03]],
#
#         [[1.2570000e+01, 3.9208639e-02],
#          [1.2570000e+01, 3.9208639e-02],
#          [1.2570000e+01, 3.9208639e-02],
#          [1.2580000e+01, 3.9599024e-02],
#          [1.2580000e+01, 3.9599024e-02],
#          [1.2580000e+01, 3.9599024e-02]],
#
#         [[1.2480000e+01, 3.5828125e-02],
#          [1.2480000e+01, 3.5828125e-02],
#          [1.2480000e+01, 3.5828125e-02],
#          [1.2480000e+01, 3.5828125e-02],
#          [1.2480000e+01, 3.5828125e-02],
#          [1.2480000e+01, 3.5828125e-02]],
#
#         [[1.2330000e+01, 3.0701710e-02],
#          [1.2310000e+01, 3.0063845e-02],
#          [1.2280000e+01, 2.9126432e-02],
#          [1.2260000e+01, 2.8514234e-02],
#          [1.2230000e+01, 2.7614763e-02],
#          [1.2210000e+01, 2.7027491e-02]],
#
#         [[1.2250000e+01, 2.8211916e-02],
#          [1.2240000e+01, 2.7912097e-02],
#          [1.2240000e+01, 2.7912097e-02],
#          [1.2240000e+01, 2.7912097e-02],
#          [1.2240000e+01, 2.7912097e-02],
#          [1.2240000e+01, 2.7912097e-02]],
#
#         [[1.1890000e+01, 1.8882351e-02],
#          [1.1890000e+01, 1.8882351e-02],
#          [1.1890000e+01, 1.8882351e-02],
#          [1.1890000e+01, 1.8882351e-02],
#          [1.1890000e+01, 1.8882351e-02],
#          [1.1890000e+01, 1.8882351e-02]],
#
#         [[1.3630000e+01, 1.0078897e-01],
#          [1.3620000e+01, 9.9982649e-02],
#          [1.3610000e+01, 9.9181324e-02],
#          [1.3600000e+01, 9.8384991e-02],
#          [1.3590000e+01, 9.7593606e-02],
#          [1.3590000e+01, 9.7593606e-02]],
#
#         [[1.3320000e+01, 7.8022890e-02],
#          [1.3320000e+01, 7.8022890e-02],
#          [1.3320000e+01, 7.8022890e-02],
#          [1.3320000e+01, 7.8022890e-02],
#          [1.3330000e+01, 7.8688413e-02],
#          [1.3320000e+01, 7.8022890e-02]],
#
#         [[1.2480000e+01, 3.5828125e-02],
#          [1.2480000e+01, 3.5828125e-02],
#          [1.2480000e+01, 3.5828125e-02],
#          [1.2480000e+01, 3.5828125e-02],
#          [1.2480000e+01, 3.5828125e-02],
#          [1.2480000e+01, 3.5828125e-02]],
#
#         [[1.1890000e+01, 1.8882351e-02],
#          [1.1890000e+01, 1.8882351e-02],
#          [1.1890000e+01, 1.8882351e-02],
#          [1.1890000e+01, 1.8882351e-02],
#          [1.1890000e+01, 1.8882351e-02],
#          [1.1890000e+01, 1.8882351e-02]],
#
#         [[1.2490000e+01, 3.6192115e-02],
#          [1.2490000e+01, 3.6192115e-02],
#          [1.2490000e+01, 3.6192115e-02],
#          [1.2490000e+01, 3.6192115e-02],
#          [1.2490000e+01, 3.6192115e-02],
#          [1.2490000e+01, 3.6192115e-02]],
#
#         [[1.2050000e+01, 2.2671245e-02],
#          [1.2050000e+01, 2.2671245e-02],
#          [1.2050000e+01, 2.2671245e-02],
#          [1.2050000e+01, 2.2671245e-02],
#          [1.2050000e+01, 2.2671245e-02],
#          [1.2050000e+01, 2.2671245e-02]],
#
#         [[1.1910000e+01, 1.9326834e-02],
#          [1.1910000e+01, 1.9326834e-02],
#          [1.1910000e+01, 1.9326834e-02],
#          [1.1910000e+01, 1.9326834e-02],
#          [1.1910000e+01, 1.9326834e-02],
#          [1.1910000e+01, 1.9326834e-02]],
#
#         [[1.2010000e+01, 2.1673022e-02],
#          [1.2010000e+01, 2.1673022e-02],
#          [1.2010000e+01, 2.1673022e-02],
#          [1.2010000e+01, 2.1673022e-02],
#          [1.2010000e+01, 2.1673022e-02],
#          [1.2010000e+01, 2.1673022e-02]],
#
#         [[1.2570000e+01, 3.9208639e-02],
#          [1.2570000e+01, 3.9208639e-02],
#          [1.2570000e+01, 3.9208639e-02],
#          [1.2570000e+01, 3.9208639e-02],
#          [1.2570000e+01, 3.9208639e-02],
#          [1.2570000e+01, 3.9208639e-02]],
#
#         [[1.2050000e+01, 2.2671245e-02],
#          [1.2050000e+01, 2.2671245e-02],
#          [1.2050000e+01, 2.2671245e-02],
#          [1.2050000e+01, 2.2671245e-02],
#          [1.2050000e+01, 2.2671245e-02],
#          [1.2060000e+01, 2.2926304e-02]],
#
#         [[1.3100000e+01, 6.4451829e-02],
#          [1.3090000e+01, 6.3881800e-02],
#          [1.3090000e+01, 6.3881800e-02],
#          [1.3170000e+01, 6.8553336e-02],
#          [1.3210000e+01, 7.0986219e-02],
#          [1.3140000e+01, 6.6771500e-02]],
#
#         [[1.4280000e+01, 1.6502498e-01],
#          [1.4280000e+01, 1.6502498e-01],
#          [1.4190000e+01, 1.5462855e-01],
#          [1.4020000e+01, 1.3637763e-01],
#          [1.3810000e+01, 1.1618366e-01],
#          [1.3640000e+01, 1.0160032e-01]],
#
#         [[1.2720000e+01, 4.5388356e-02],
#          [1.2710000e+01, 4.4954270e-02],
#          [1.2710000e+01, 4.4954270e-02],
#          [1.2710000e+01, 4.4954270e-02],
#          [1.2710000e+01, 4.4954270e-02],
#          [1.2700000e+01, 4.4523414e-02]],
#
#         [[1.1870000e+01, 1.8445874e-02],
#          [1.1870000e+01, 1.8445874e-02],
#          [1.1870000e+01, 1.8445874e-02],
#          [1.1870000e+01, 1.8445874e-02],
#          [1.1870000e+01, 1.8445874e-02],
#          [1.1870000e+01, 1.8445874e-02]],
#
#         [[1.1870000e+01, 1.8445874e-02],
#          [1.1870000e+01, 1.8445874e-02],
#          [1.1870000e+01, 1.8445874e-02],
#          [1.1870000e+01, 1.8445874e-02],
#          [1.1870000e+01, 1.8445874e-02],
#          [1.1870000e+01, 1.8445874e-02]]], dtype=float32)>)

# %%
# The conv window is used for the Convolutional Neural Netwrok
# 6 consecutive hours of data are used together to make predictions one hour into the future
CONV_WIDTH = 6
conv_window = WindowGenerator(
        input_width=CONV_WIDTH,
        label_width=1,
        shift=1,
        label_columns=['Waterlevel_Sto_Nino', 'Velocity_Sto_Nino']
    )

conv_window
# Out:
# Total window size: 7
# Input indices: [0 1 2 3 4 5]
# Label indices: [6]
# Label column name(s): ['Waterlevel_Sto_Nino', 'Velocity_Sto_Nino']

# %%
for example_inputs, example_labels in conv_window.train.take(1):
    print(f'Inputs shape (batch, time, features): {example_inputs.shape}')
    print(f'Labels shape (batch, time, features): {example_labels.shape}')
# Out:
# Inputs shape (batch, time, features): (32, 6, 7)
# Labels shape (batch, time, features): (32, 1, 2)

# %% [markdown]
# ## Metrics

# %%
def r_square(y_true, y_pred):
    x = y_true
    y = y_pred
    mx = K.mean(x, axis=0)
    my = K.mean(y, axis=0)
    xm, ym = x - mx, y - my
    r_num = K.square(K.sum(xm * ym))
    x_square_sum = K.sum(xm * xm)
    y_square_sum = K.sum(ym * ym)
    r_den = (x_square_sum * y_square_sum) + K.epsilon()
    
    r = r_num / r_den
    return r

# %%
def NSE(y_true, y_pred):
    '''
    This is the Nash-Sutcliffe Efficiency Coefficient
    '''
    y_pred = K.flatten(y_pred)
    y_true = K.flatten(y_true)

    
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ## Training Loop

# %%
# For easy compiling and fitting of different models
MAX_EPOCHS = 20

def compile_and_fit(model, window, patience=2):
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, mode='min')

    model.compile(
        loss=tf.keras.losses.MeanSquaredError(), 
        optimizer='adam', 
        metrics=[tf.keras.metrics.MeanSquaredError(), NSE, r_square]
    )

    history = model.fit(
        window.train, 
        epochs=MAX_EPOCHS,
        validation_data=window.val,
        callbacks=[early_stopping]
    )

    return history

# %% [markdown]
# ## Models

# %%
# Dense Neural Network
dense = tf.keras.Sequential([
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=2)
])

# Convolution Neural Network
conv_model = tf.keras.Sequential([
    tf.keras.layers.Conv1D(filters=64, kernel_size=(CONV_WIDTH,), activation='relu'),
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=2),
])

# LSTM
lstm_model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(128, return_sequences=True),
    tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dense(units=2)
])

# %% [markdown]
# ## Training

# %%
dense_history = compile_and_fit(dense, wide_window)
# Out:
# Epoch 1/20
# 274/274 [==============================] - 3s 5ms/step - loss: 11370805248.0000 - mean_squared_error: 11370789888.0000 - NSE: -298587040.0000 - r_square: 0.2386 - val_loss: 284407104.0000 - val_mean_squared_error: 284407104.0000 - val_NSE: -7982022.0000 - val_r_square: 0.0475
# Epoch 2/20
# 274/274 [==============================] - 1s 4ms/step - loss: 649594.5000 - mean_squared_error: 649594.4375 - NSE: -17021.8477 - r_square: 0.2167 - val_loss: 315686.6250 - val_mean_squared_error: 315686.5938 - val_NSE: -8857.7754 - val_r_square: 0.2503
# Epoch 3/20
# 274/274 [==============================] - 1s 4ms/step - loss: 105581.8906 - mean_squared_error: 105581.8906 - NSE: -2756.2527 - r_square: 0.2111 - val_loss: 1185414.6250 - val_mean_squared_error: 1185414.5000 - val_NSE: -33262.3320 - val_r_square: 0.0336
# Epoch 4/20
# 274/274 [==============================] - 1s 4ms/step - loss: 76068072.0000 - mean_squared_error: 76068064.0000 - NSE: -1982066.5000 - r_square: 0.2013 - val_loss: 709393472.0000 - val_mean_squared_error: 709393408.0000 - val_NSE: -19907596.0000 - val_r_square: 0.0719

# %%
conv_history = compile_and_fit(conv_model, conv_window)
# Out:
# Epoch 1/20
# 274/274 [==============================] - 3s 5ms/step - loss: 9980663808.0000 - mean_squared_error: 9980663808.0000 - NSE: -261000560.0000 - r_square: 0.1166 - val_loss: 1175633.3750 - val_mean_squared_error: 1175633.3750 - val_NSE: -33001.1406 - val_r_square: 0.0684
# Epoch 2/20
# 274/274 [==============================] - 1s 4ms/step - loss: 417888.8125 - mean_squared_error: 417888.8125 - NSE: -10936.8203 - r_square: 0.0698 - val_loss: 2169681.5000 - val_mean_squared_error: 2169681.5000 - val_NSE: -60888.3516 - val_r_square: 0.1098
# Epoch 3/20
# 274/274 [==============================] - 1s 4ms/step - loss: 417639.6250 - mean_squared_error: 417639.6250 - NSE: -10887.6152 - r_square: 0.0705 - val_loss: 596828.6875 - val_mean_squared_error: 596828.6875 - val_NSE: -16755.5508 - val_r_square: 1.1054e-04
# Epoch 4/20
# 274/274 [==============================] - 1s 4ms/step - loss: 7800623.0000 - mean_squared_error: 7800623.0000 - NSE: -216178.2969 - r_square: 0.1082 - val_loss: 2735760640.0000 - val_mean_squared_error: 2735760640.0000 - val_NSE: -76782144.0000 - val_r_square: 0.2690
# Epoch 5/20
# 274/274 [==============================] - 1s 3ms/step - loss: 40998960.0000 - mean_squared_error: 40998960.0000 - NSE: -1067278.0000 - r_square: 0.1224 - val_loss: 1168597.7500 - val_mean_squared_error: 1168597.7500 - val_NSE: -32806.7305 - val_r_square: 0.0927

# %%
lstm_history = compile_and_fit(lstm_model, wide_window)
# Out:
# Epoch 1/20
# 274/274 [==============================] - 6s 12ms/step - loss: 4.2231 - mean_squared_error: 4.2231 - NSE: 0.8894 - r_square: 0.0042 - val_loss: 0.1738 - val_mean_squared_error: 0.1738 - val_NSE: 0.9951 - val_r_square: 1.4643e-14
# Epoch 2/20
# 274/274 [==============================] - 3s 9ms/step - loss: 0.2508 - mean_squared_error: 0.2508 - NSE: 0.9935 - r_square: 1.5285e-04 - val_loss: 0.0907 - val_mean_squared_error: 0.0907 - val_NSE: 0.9975 - val_r_square: 1.4271e-14
# Epoch 3/20
# 274/274 [==============================] - 3s 10ms/step - loss: 0.2367 - mean_squared_error: 0.2367 - NSE: 0.9939 - r_square: 1.6318e-04 - val_loss: 0.0943 - val_mean_squared_error: 0.0943 - val_NSE: 0.9974 - val_r_square: 1.4351e-14
# Epoch 4/20
# 274/274 [==============================] - 3s 10ms/step - loss: 0.2376 - mean_squared_error: 0.2376 - NSE: 0.9938 - r_square: 9.5520e-05 - val_loss: 0.0709 - val_mean_squared_error: 0.0709 - val_NSE: 0.9980 - val_r_square: 3.0402e-15
# Epoch 5/20
# 274/274 [==============================] - 3s 10ms/step - loss: 0.2397 - mean_squared_error: 0.2397 - NSE: 0.9938 - r_square: 6.4503e-04 - val_loss: 0.1510 - val_mean_squared_error: 0.1510 - val_NSE: 0.9958 - val_r_square: 3.2448e-15
# Epoch 6/20
# 274/274 [==============================] - 2s 9ms/step - loss: 0.2391 - mean_squared_error: 0.2391 - NSE: 0.9938 - r_square: 1.8149e-04 - val_loss: 0.0488 - val_mean_squared_error: 0.0488 - val_NSE: 0.9986 - val_r_square: 1.5936e-14
# Epoch 7/20
# 274/274 [==============================] - 3s 10ms/step - loss: 0.2470 - mean_squared_error: 0.2470 - NSE: 0.9936 - r_square: 3.1385e-04 - val_loss: 0.1381 - val_mean_squared_error: 0.1381 - val_NSE: 0.9961 - val_r_square: 1.3374e-14
# Epoch 8/20
# 274/274 [==============================] - 3s 10ms/step - loss: 0.2426 - mean_squared_error: 0.2426 - NSE: 0.9937 - r_square: 2.1492e-04 - val_loss: 0.1254 - val_mean_squared_error: 0.1254 - val_NSE: 0.9965 - val_r_square: 2.7343e-15

# %% [markdown]
# ## Predictions

# %%
test_df
# Out:
#            x           t  Discharge_Sto_Nino  Waterlevel_Sto_Nino  \
# 13140  14420  47390400.0           14.817736                11.89
# 13141  14420  47394000.0           14.450867                11.87
# 13142  14420  47397600.0           14.091331                11.85
# 13143  14420  47401200.0           13.914278                11.84
# 13144  14420  47404800.0           13.914278                11.84
# ...      ...         ...                 ...                  ...
# 17515  14420  63140400.0           28.244204                12.44
# 17516  14420  63144000.0           28.244204                12.44
# 17517  14420  63147600.0           28.244204                12.44
# 17518  14420  63151200.0           28.244204                12.44
# 17519  14420  63154800.0           28.244204                12.44
#
#        Velocity_Sto_Nino  friction_coeff     slope
# 13140           0.018882           0.033  0.000667
# 13141           0.018446           0.033  0.000667
# 13142           0.018017           0.033  0.000667
# 13143           0.017806           0.033  0.000667
# 13144           0.017806           0.033  0.000667
# ...                  ...             ...       ...
# 17515           0.034401           0.033  0.000667
# 17516           0.034401           0.033  0.000667
# 17517           0.034401           0.033  0.000667
# 17518           0.034401           0.033  0.000667
# 17519           0.034401           0.033  0.000667
#
# [4380 rows x 7 columns]

# %%
y_true = test_df[['Waterlevel_Sto_Nino', 'Velocity_Sto_Nino']]
y_true = y_true.values
y_true
# Out:
# array([[11.89      ,  0.01888235],
#        [11.87      ,  0.01844587],
#        [11.85      ,  0.0180173 ],
#        ...,
#        [12.44      ,  0.03440052],
#        [12.44      ,  0.03440052],
#        [12.44      ,  0.03440052]])

# %%
y_true_h = y_true[1:,0]
y_true_v = y_true[1:,1]

# %%
y_true_h
# Out:
# array([11.87, 11.85, 11.84, ..., 12.44, 12.44, 12.44])

# %%
y_true_h.shape
# Out:
# (4379,)

# %%
y_true_v
# Out:
# array([0.01844587, 0.0180173 , 0.01780595, ..., 0.03440052, 0.03440052,
#        0.03440052])

# %%
y_true_v.shape
# Out:
# (4379,)

# %%
y_pred_h = []
y_pred_v = []
batch_num = 1

for x, y in wide_window.test:
    predictions = lstm_model(x)
    
    if batch_num == 1:
        for i in range(len(predictions[0])):
            y_pred_h.append(predictions[0][i][0])
            y_pred_v.append(predictions[0][i][1])
            
        for i in range(1, len(predictions)):
            y_pred_h.append(predictions[i][-1][0])
            y_pred_v.append(predictions[i][-1][1])
            
        batch_num += 1
        
    else:
        for i in range(len(predictions)):
            y_pred_h.append(predictions[i][-1][0])
            y_pred_v.append(predictions[i][-1][1])
            
y_pred_h = np.array(y_pred_h)
y_pred_v = np.array(y_pred_v)

# %%
np.set_printoptions(suppress=True)

# %%
for x, y in wide_window.test.take(1):
    print(x[:10])
    print(lstm_model(x[:10]))
    print(y[:10])
# Out:
# tf.Tensor(
# [[[   14420.         47390400.               14.817737
#          11.89              0.01888235        0.033
#           0.00066667]
#   [   14420.         47394000.               14.450867
#          11.87              0.01844587        0.033
#           0.00066667]
#   [   14420.         47397600.               14.0913315
#          11.85              0.0180173         0.033
#           0.00066667]
#   [   14420.         47401200.               13.914278
#          11.84              0.01780595        0.033
#           0.00066667]
#   [   14420.         47404800.               13.914278
#          11.84              0.01780595        0.033
#           0.00066667]
#   [   14420.         47408400.               23.072578
#          12.26              0.02851423        0.033
#           0.00066667]]
#
#  [[   14420.         47394000.               14.450867
#          11.87              0.01844587        0.033
#           0.00066667]
#   [   14420.         47397600.               14.0913315
#          11.85              0.0180173         0.033
#           0.00066667]
#   [   14420.         47401200.               13.914278
#          11.84              0.01780595        0.033
#           0.00066667]
#   [   14420.         47404800.               13.914278
#          11.84              0.01780595        0.033
#           0.00066667]
#   [   14420.         47408400.               23.072578
#          12.26              0.02851423        0.033
#           0.00066667]
#   [   14420.         47412000.               34.673985
#          12.63              0.04159647        0.033
#           0.00066667]]
#
#  [[   14420.         47397600.               14.0913315
#          11.85              0.0180173         0.033
#           0.00066667]
#   [   14420.         47401200.               13.914278
#          11.84              0.01780595        0.033
#           0.00066667]
#   [   14420.         47404800.               13.914278
#          11.84              0.01780595        0.033
#           0.00066667]
#   [   14420.         47408400.               23.072578
#          12.26              0.02851423        0.033
#           0.00066667]
#   [   14420.         47412000.               34.673985
#          12.63              0.04159647        0.033
#           0.00066667]
#   [   14420.         47415600.               41.80241
#          12.81              0.04944339        0.033
#           0.00066667]]
#
#  [[   14420.         47401200.               13.914278
#          11.84              0.01780595        0.033
#           0.00066667]
#   [   14420.         47404800.               13.914278
#          11.84              0.01780595        0.033
#           0.00066667]
#   [   14420.         47408400.               23.072578
#          12.26              0.02851423        0.033
#           0.00066667]
#   [   14420.         47412000.               34.673985
#          12.63              0.04159647        0.033
#           0.00066667]
#   [   14420.         47415600.               41.80241
#          12.81              0.04944339        0.033
#           0.00066667]
#   [   14420.         47419200.               41.37784
#          12.8               0.04897945        0.033
#           0.00066667]]
#
#  [[   14420.         47404800.               13.914278
#          11.84              0.01780595        0.033
#           0.00066667]
#   [   14420.         47408400.               23.072578
#          12.26              0.02851423        0.033
#           0.00066667]
#   [   14420.         47412000.               34.673985
#          12.63              0.04159647        0.033
#           0.00066667]
#   [   14420.         47415600.               41.80241
#          12.81              0.04944339        0.033
#           0.00066667]
#   [   14420.         47419200.               41.37784
#          12.8               0.04897945        0.033
#           0.00066667]
#   [   14420.         47422800.               36.54766
#          12.68              0.04367133        0.033
#           0.00066667]]
#
#  [[   14420.         47408400.               23.072578
#          12.26              0.02851423        0.033
#           0.00066667]
#   [   14420.         47412000.               34.673985
#          12.63              0.04159647        0.033
#           0.00066667]
#   [   14420.         47415600.               41.80241
#          12.81              0.04944339        0.033
#           0.00066667]
#   [   14420.         47419200.               41.37784
#          12.8               0.04897945        0.033
#           0.00066667]
#   [   14420.         47422800.               36.54766
#          12.68              0.04367133        0.033
#           0.00066667]
#   [   14420.         47426400.               30.490564
#          12.51              0.03692872        0.033
#           0.00066667]]
#
#  [[   14420.         47412000.               34.673985
#          12.63              0.04159647        0.033
#           0.00066667]
#   [   14420.         47415600.               41.80241
#          12.81              0.04944339        0.033
#           0.00066667]
#   [   14420.         47419200.               41.37784
#          12.8               0.04897945        0.033
#           0.00066667]
#   [   14420.         47422800.               36.54766
#          12.68              0.04367133        0.033
#           0.00066667]
#   [   14420.         47426400.               30.490564
#          12.51              0.03692872        0.033
#           0.00066667]
#   [   14420.         47430000.               25.841799
#          12.36              0.03167819        0.033
#           0.00066667]]
#
#  [[   14420.         47415600.               41.80241
#          12.81              0.04944339        0.033
#           0.00066667]
#   [   14420.         47419200.               41.37784
#          12.8               0.04897945        0.033
#           0.00066667]
#   [   14420.         47422800.               36.54766
#          12.68              0.04367133        0.033
#           0.00066667]
#   [   14420.         47426400.               30.490564
#          12.51              0.03692872        0.033
#           0.00066667]
#   [   14420.         47430000.               25.841799
#          12.36              0.03167819        0.033
#           0.00066667]
#   [   14420.         47433600.               22.548508
#          12.24              0.0279121         0.033
#           0.00066667]]
#
#  [[   14420.         47419200.               41.37784
#          12.8               0.04897945        0.033
#           0.00066667]
#   [   14420.         47422800.               36.54766
#          12.68              0.04367133        0.033
#           0.00066667]
#   [   14420.         47426400.               30.490564
#          12.51              0.03692872        0.033
#           0.00066667]
#   [   14420.         47430000.               25.841799
#          12.36              0.03167819        0.033
#           0.00066667]
#   [   14420.         47433600.               22.548508
#          12.24              0.0279121         0.033
#           0.00066667]
#   [   14420.         47437200.               21.033407
#          12.18              0.02616486        0.033
#           0.00066667]]
#
#  [[   14420.         47422800.               36.54766
#          12.68              0.04367133        0.033
#           0.00066667]
#   [   14420.         47426400.               30.490564
#          12.51              0.03692872        0.033
#           0.00066667]
#   [   14420.         47430000.               25.841799
#          12.36              0.03167819        0.033
#           0.00066667]
#   [   14420.         47433600.               22.548508
#          12.24              0.0279121         0.033
#           0.00066667]
#   [   14420.         47437200.               21.033407
#          12.18              0.02616486        0.033
#           0.00066667]
#   [   14420.         47440800.               20.546968
#          12.16              0.02560179        0.033
#           0.00066667]]], shape=(10, 6, 7), dtype=float32)
# tf.Tensor(
# [[[12.361591    0.09318501]
#   [12.36402     0.08962568]
#   [12.372158    0.0898837 ]
#   [12.375034    0.09014913]
#   [12.375424    0.09018505]
#   [12.375477    0.09019002]]
#
#  [[12.361591    0.09318501]
#   [12.36402     0.08962568]
#   [12.372158    0.0898837 ]
#   [12.375034    0.09014913]
#   [12.375424    0.09018505]
#   [12.375477    0.09019002]]
#
#  [[12.361591    0.09318501]
#   [12.36402     0.08962568]
#   [12.372158    0.0898837 ]
#   [12.375034    0.09014913]
#   [12.375424    0.09018505]
#   [12.375477    0.09019002]]
#
#  [[12.361591    0.09318501]
#   [12.36402     0.08962568]
#   [12.372158    0.0898837 ]
#   [12.375034    0.09014913]
#   [12.375424    0.09018505]
#   [12.375477    0.09019002]]
#
#  [[12.361591    0.09318501]
#   [12.36402     0.08962568]
#   [12.372158    0.0898837 ]
#   [12.375034    0.09014913]
#   [12.375424    0.09018505]
#   [12.375477    0.09019002]]
#
#  [[12.361591    0.09318501]
#   [12.36402     0.08962568]
#   [12.372158    0.0898837 ]
#   [12.375034    0.09014913]
#   [12.375424    0.09018505]
#   [12.375477    0.09019002]]
#
#  [[12.361591    0.09318501]
#   [12.36402     0.08962568]
#   [12.372158    0.0898837 ]
#   [12.375034    0.09014913]
#   [12.375424    0.09018505]
#   [12.375477    0.09019002]]
#
#  [[12.361591    0.09318501]
#   [12.36402     0.08962568]
#   [12.372158    0.0898837 ]
#   [12.375034    0.09014913]
#   [12.375424    0.09018505]
#   [12.375477    0.09019002]]
#
#  [[12.361591    0.09318501]
#   [12.36402     0.08962568]
#   [12.372158    0.0898837 ]
#   [12.375034    0.09014913]
#   [12.375424    0.09018505]
#   [12.375477    0.09019002]]
#
#  [[12.361591    0.09318501]
#   [12.36402     0.08962568]
#   [12.372158    0.0898837 ]
#   [12.375034    0.09014913]
#   [12.375424    0.09018505]
#   [12.375477    0.09019002]]], shape=(10, 6, 2), dtype=float32)
# tf.Tensor(
# [[[11.87        0.01844587]
#   [11.85        0.0180173 ]
#   [11.84        0.01780595]
#   [11.84        0.01780595]
#   [12.26        0.02851423]
#   [12.63        0.04159647]]
#
#  [[11.85        0.0180173 ]
#   [11.84        0.01780595]
#   [11.84        0.01780595]
#   [12.26        0.02851423]
#   [12.63        0.04159647]
#   [12.81        0.04944339]]
#
#  [[11.84        0.01780595]
#   [11.84        0.01780595]
#   [12.26        0.02851423]
#   [12.63        0.04159647]
#   [12.81        0.04944339]
#   [12.8         0.04897945]]
#
#  [[11.84        0.01780595]
#   [12.26        0.02851423]
#   [12.63        0.04159647]
#   [12.81        0.04944339]
#   [12.8         0.04897945]
#   [12.68        0.04367133]]
#
#  [[12.26        0.02851423]
#   [12.63        0.04159647]
#   [12.81        0.04944339]
#   [12.8         0.04897945]
#   [12.68        0.04367133]
#   [12.51        0.03692872]]
#
#  [[12.63        0.04159647]
#   [12.81        0.04944339]
#   [12.8         0.04897945]
#   [12.68        0.04367133]
#   [12.51        0.03692872]
#   [12.36        0.03167819]]
#
#  [[12.81        0.04944339]
#   [12.8         0.04897945]
#   [12.68        0.04367133]
#   [12.51        0.03692872]
#   [12.36        0.03167819]
#   [12.24        0.0279121 ]]
#
#  [[12.8         0.04897945]
#   [12.68        0.04367133]
#   [12.51        0.03692872]
#   [12.36        0.03167819]
#   [12.24        0.0279121 ]
#   [12.18        0.02616486]]
#
#  [[12.68        0.04367133]
#   [12.51        0.03692872]
#   [12.36        0.03167819]
#   [12.24        0.0279121 ]
#   [12.18        0.02616486]
#   [12.16        0.02560179]]
#
#  [[12.51        0.03692872]
#   [12.36        0.03167819]
#   [12.24        0.0279121 ]
#   [12.18        0.02616486]
#   [12.16        0.02560179]
#   [12.16        0.02560179]]], shape=(10, 6, 2), dtype=float32)

# %%
y_pred_h
# Out:
# array([12.361591, 12.36402 , 12.372158, ..., 12.375477, 12.375477,
#        12.375477], dtype=float32)

# %%
y_pred_h.shape
# Out:
# (4379,)

# %%
y_pred_v
# Out:
# array([0.09318501, 0.08962568, 0.0898837 , ..., 0.09019002, 0.09019002,
#        0.09019002], dtype=float32)

# %%
y_pred_v.shape
# Out:
# (4379,)

# %%
SS_res_h = np.sum(np.square(y_true_h - y_pred_h)) 
SS_tot_h = np.sum(np.square(y_true_h - np.mean(y_true_h))) 

nse_h =  1 - SS_res_h/SS_tot_h
nse_h
# Out:
# -0.21938747354398025

# %%
SS_res_v = np.sum(np.square(y_true_v - y_pred_v)) 
SS_tot_v = np.sum(np.square(y_true_v - np.mean(y_true_v))) 

nse_v =  1 - SS_res_v/SS_tot_v
nse_v
# Out:
# -1.0608529502231288

# %%
mse_h = np.mean(np.square(y_true_h-y_pred_h))
mse_h
# Out:
# 0.37852563225701424

# %%
mse_v = np.mean(np.square(y_true_v-y_pred_v))
mse_v
# Out:
# 0.0034799597625944628

# %%
np.savetxt('multivariate_lstm_window_mahesh_inputs_predictions.csv', y_pred_h, delimiter=',', fmt='%.4f')
