# %%
import tensorflow as tf
import pandas as pd
import os
import numpy as np
import datetime as dt
from random import seed
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import backend as K
tf.compat.v1.experimental.output_all_intermediates(True)

# %%
tf.random.set_seed(36)

# %% [markdown]
# ## Dataset

# %%
BASE_DIR_PATH = '../Datasets/typhoons'
TRAIN_PATH = os.path.join(BASE_DIR_PATH, 'train')
VAL_PATH = os.path.join(BASE_DIR_PATH, 'val')
TEST_PATH = os.path.join(BASE_DIR_PATH, 'test')

# %%
def load_files(file_path):
    '''
    Loading the files from file_path as pandas DataFrames and combining them
    '''
    file_names = os.listdir(file_path)
    print(file_names)
    
    df = None
    
    for i, file in enumerate(file_names):
        if i == 0:
            df = pd.read_csv(os.path.join(file_path, file))
        else:
            tmp = pd.read_csv(os.path.join(file_path, file))
            df = pd.concat([df, tmp])
    
    return df

# %%
train_df = load_files(TRAIN_PATH)
train_df
# Out:
# ['ambo_2016.csv', 'auring_2017.csv', 'bising_2017.csv', 'butchoy_2016.csv', 'carina_2016.csv', 'crising_2017.csv', 'dante_2017.csv', 'dindo_2016.csv', 'emong_2017.csv', 'enteng_2016.csv', 'fabian_2017.csv', 'ferdie_2016.csv', 'gener_2016.csv', 'helen_2016.csv', 'igme_2016.csv', 'julian_2016.csv', 'karen_2016.csv', 'lawin_2016.csv', 'marce_2016.csv', 'nina_2016.csv']
#      Unnamed: 0             datetime  month  day  hour         t    Station  \
# 0          8448  2016-06-26 00:00:00      6   26     0       0.0  Montalban
# 1          8449  2016-06-26 00:00:00      6   26     0       0.0   Sto_Nino
# 2          8450  2016-06-26 01:00:00      6   26     1    3600.0  Montalban
# 3          8451  2016-06-26 01:00:00      6   26     1    3600.0   Sto_Nino
# 4          8452  2016-06-26 02:00:00      6   26     2    7200.0  Montalban
# ..          ...                  ...    ...  ...   ...       ...        ...
# 235       17323  2016-12-27 21:00:00     12   27    21  421200.0   Sto_Nino
# 236       17324  2016-12-27 22:00:00     12   27    22  424800.0  Montalban
# 237       17325  2016-12-27 22:00:00     12   27    22  424800.0   Sto_Nino
# 238       17326  2016-12-27 23:00:00     12   27    23  428400.0  Montalban
# 239       17327  2016-12-27 23:00:00     12   27    23  428400.0   Sto_Nino
#
#          x  Rainfall_Aries  Rainfall_Boso  Rainfall_Campana  Rainfall_Nangka  \
# 0        0               0              0                 0                0
# 1    14420               0              0                 0                0
# 2        0               0              0                 0                0
# 3    14420               0              0                 0                0
# 4        0               0              0                 0                0
# ..     ...             ...            ...               ...              ...
# 235  14420               0              0                 0                0
# 236      0               0              0                 0                0
# 237  14420               0              0                 0                0
# 238      0               0              0                 0                0
# 239  14420               0              0                 0                0
#
#      Rainfall_Oro  Waterlevel  Discharge  Cross_Section  Velocity  fric_coeff  \
# 0               0       20.52   8.918747         615.60  0.014488       0.035
# 1               0       11.95  15.963477         788.70  0.020240       0.033
# 2               0       20.52   8.918747         615.60  0.014488       0.035
# 3               0       11.95  15.963477         788.70  0.020240       0.033
# 4               0       20.51   8.829671         615.30  0.014350       0.035
# ..            ...         ...        ...            ...       ...         ...
# 235             0       12.68  36.547660         836.88  0.043671       0.033
# 236             0       21.50  23.628236         645.00  0.036633       0.035
# 237             0       12.67  36.166567         836.22  0.043250       0.033
# 238             0       21.50  23.628236         645.00  0.036633       0.035
# 239             0       12.65  35.413959         834.90  0.042417       0.033
#
#         slope
# 0    0.002000
# 1    0.000667
# 2    0.002000
# 3    0.000667
# 4    0.002000
# ..        ...
# 235  0.000667
# 236  0.002000
# 237  0.000667
# 238  0.002000
# 239  0.000667
#
# [3792 rows x 19 columns]

# %%
val_df = load_files(VAL_PATH)
val_df
# Out:
# ['gorio_2017.csv', 'isang_2017.csv', 'jolina_2017.csv', 'kiko_2017.csv', 'lannie_2017.csv', 'nando_2017.csv', 'odette_2017.csv']
#      Unnamed: 0             datetime  month  day  hour         t    Station  \
# 0         27360  2017-07-25 00:00:00      7   25     0       0.0  Montalban
# 1         27361  2017-07-25 00:00:00      7   25     0       0.0   Sto_Nino
# 2         27362  2017-07-25 01:00:00      7   25     1    3600.0  Montalban
# 3         27363  2017-07-25 01:00:00      7   25     1    3600.0   Sto_Nino
# 4         27364  2017-07-25 02:00:00      7   25     2    7200.0  Montalban
# ..          ...                  ...    ...  ...   ...       ...        ...
# 235       31339  2017-10-15 21:00:00     10   15    21  421200.0   Sto_Nino
# 236       31340  2017-10-15 22:00:00     10   15    22  424800.0  Montalban
# 237       31341  2017-10-15 22:00:00     10   15    22  424800.0   Sto_Nino
# 238       31342  2017-10-15 23:00:00     10   15    23  428400.0  Montalban
# 239       31343  2017-10-15 23:00:00     10   15    23  428400.0   Sto_Nino
#
#          x  Rainfall_Aries  Rainfall_Boso  Rainfall_Campana  Rainfall_Nangka  \
# 0        0               0              0                 0                0
# 1    14420               0              0                 0                0
# 2        0               0              0                 0                0
# 3    14420               0              0                 0                0
# 4        0               0              0                 0                1
# ..     ...             ...            ...               ...              ...
# 235  14420               0              0                 0                0
# 236      0               0              0                 0                0
# 237  14420               0              0                 0                0
# 238      0               0              0                 0                0
# 239  14420               0              0                 0                0
#
#      Rainfall_Oro  Waterlevel  Discharge  Cross_Section  Velocity  fric_coeff  \
# 0               0       21.32  19.783987         639.60  0.030932       0.035
# 1               0       12.47  29.190037         823.02  0.035467       0.033
# 2               0       22.37  55.264986         671.10  0.082350       0.035
# 3               0       12.51  30.490564         825.66  0.036929       0.033
# 4               0       22.72  77.481767         681.60  0.113676       0.035
# ..            ...         ...        ...            ...       ...         ...
# 235             0       12.79  40.956736         844.14  0.048519       0.033
# 236             0       21.68  28.202195         650.40  0.043361       0.035
# 237             0       12.77  40.124861         842.82  0.047608       0.033
# 238             0       21.67  27.926745         650.10  0.042958       0.035
# 239             0       12.76  39.714046         842.16  0.047157       0.033
#
#         slope
# 0    0.002000
# 1    0.000667
# 2    0.002000
# 3    0.000667
# 4    0.002000
# ..        ...
# 235  0.000667
# 236  0.002000
# 237  0.000667
# 238  0.002000
# 239  0.000667
#
# [1584 rows x 19 columns]

# %%
test_df = load_files(TEST_PATH)
test_df
# Out:
# ['paolo_2017.csv', 'quedan_2017.csv', 'ramil_2017.csv', 'salome_2017.csv', 'tino_2017.csv', 'urduja_2017.csv', 'vinta_2017.csv']
#      Unnamed: 0             datetime  month  day  hour         t    Station  \
# 0         31344  2017-10-16 00:00:00     10   16     0       0.0  Montalban
# 1         31345  2017-10-16 00:00:00     10   16     0       0.0   Sto_Nino
# 2         31346  2017-10-16 01:00:00     10   16     1    3600.0  Montalban
# 3         31347  2017-10-16 01:00:00     10   16     1    3600.0   Sto_Nino
# 4         31348  2017-10-16 02:00:00     10   16     2    7200.0  Montalban
# ..          ...                  ...    ...  ...   ...       ...        ...
# 235       20155  2017-02-24 21:00:00      2   24    21  421200.0   Sto_Nino
# 236       20156  2017-02-24 22:00:00      2   24    22  424800.0  Montalban
# 237       20157  2017-02-24 22:00:00      2   24    22  424800.0   Sto_Nino
# 238       20158  2017-02-24 23:00:00      2   24    23  428400.0  Montalban
# 239       20159  2017-02-24 23:00:00      2   24    23  428400.0   Sto_Nino
#
#          x  Rainfall_Aries  Rainfall_Boso  Rainfall_Campana  Rainfall_Nangka  \
# 0        0               0              0                 0                0
# 1    14420               0              0                 0                0
# 2        0               0              0                 0                0
# 3    14420               0              0                 0                0
# 4        0               0              0                 0                0
# ..     ...             ...            ...               ...              ...
# 235  14420               0              0                 0                0
# 236      0               0              0                 0                0
# 237  14420               0              0                 0                0
# 238      0               0              0                 0                0
# 239  14420               0              0                 0                0
#
#      Rainfall_Oro  Waterlevel  Discharge  Cross_Section  Velocity  fric_coeff  \
# 0               0       21.67  27.926745         650.10  0.042958       0.035
# 1               0       12.74  38.902552         840.84  0.046266       0.033
# 2               0       21.66  27.653933         649.80  0.042558       0.035
# 3               0       12.71  37.710339         838.86  0.044954       0.033
# 4               0       21.66  27.653933         649.80  0.042558       0.035
# ..            ...         ...        ...            ...       ...         ...
# 235             0       11.82  13.565535         780.12  0.017389       0.033
# 236             0       20.95  13.707290         628.50  0.021810       0.035
# 237             0       11.82  13.565535         780.12  0.017389       0.033
# 238             0       20.95  13.707290         628.50  0.021810       0.035
# 239             0       11.82  13.565535         780.12  0.017389       0.033
#
#         slope
# 0    0.002000
# 1    0.000667
# 2    0.002000
# 3    0.000667
# 4    0.002000
# ..        ...
# 235  0.000667
# 236  0.002000
# 237  0.000667
# 238  0.002000
# 239  0.000667
#
# [1536 rows x 19 columns]

# %%
train_df = train_df.sample(frac=1)
val_df = val_df.sample(frac=1)

# %%
# all inputs
X_train = np.array(train_df[['Rainfall_Aries', 'Rainfall_Boso', 'Rainfall_Campana', 'Rainfall_Nangka', 'Rainfall_Oro', 'x' ,'t', 'fric_coeff', 'slope']].values.tolist())
X_val = np.array(val_df[['Rainfall_Aries', 'Rainfall_Boso', 'Rainfall_Campana', 'Rainfall_Nangka', 'Rainfall_Oro', 'x','t', 'fric_coeff', 'slope']].values.tolist())
X_test = np.array(test_df[['Rainfall_Aries', 'Rainfall_Boso', 'Rainfall_Campana', 'Rainfall_Nangka', 'Rainfall_Oro', 'x','t', 'fric_coeff', 'slope']].values.tolist())
Y_train = np.array(train_df[['Velocity','Waterlevel']].values.tolist())
Y_val = np.array(val_df[['Velocity','Waterlevel']].values.tolist())
Y_test = np.array(test_df[['Velocity','Waterlevel']].values.tolist())

# %%
X_train.shape
# Out:
# (3792, 9)

# %% [markdown]
# ## Metrics

# %%
def r_square(y_true, y_pred):
    x = y_true
    y = y_pred
    mx = K.mean(x, axis=0)
    my = K.mean(y, axis=0)
    xm, ym = x - mx, y - my
    r_num = K.square(K.sum(xm * ym))
    x_square_sum = K.sum(xm * xm)
    y_square_sum = K.sum(ym * ym)
    r_den = (x_square_sum * y_square_sum) + K.epsilon()
    
    r = r_num / r_den
    return r

# %%
def NSE(y_true, y_pred):
    '''
    This is the Nash-Sutcliffe Efficiency Coefficient
    '''
    y_pred = K.flatten(y_pred)
    y_true = K.flatten(y_true)

    
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ## Models and Training Loops

# %%
def create_train_dnn_model(X_train=X_train, y_train=Y_train, X_val=X_val, y_val=Y_val, max_epochs=20, patience=2,
                          n1=64, n2=64, n3=64, lr=0.001):
    # Create the model
    model = models.Sequential([
        layers.Dense(n1, activation='relu', input_shape=(X_train.shape[1],)),
        layers.Dense(n2, activation='relu'),
        layers.Dense(n3, activation='relu'),
        layers.Dense(2, activation='linear')  # 2 outputs: velocity and water level
    ])
    
    # Define early stopping callback
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=patience,
        mode='min',
        restore_best_weights=True
    )
    
    # Compile the model
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss=tf.keras.losses.MeanSquaredError(),
        metrics=[tf.keras.metrics.MeanSquaredError(), NSE, r_square]
    )
    
    # Train the model
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=max_epochs,
        callbacks=[early_stopping]
    )
    
    return model, history

# %%
def create_train_cnn_model(X_train=X_train, y_train=Y_train, X_val=X_val, y_val=Y_val, max_epochs=20, patience=2,
                          n1=64, n2=64, n3=64, lr=0.001):
    # Reshape input for 1D CNN
    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
    X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)
    
    conv_model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(X_train.shape[1], 1)),
        tf.keras.layers.Conv1D(filters=n1, kernel_size=6, activation='relu'),
        tf.keras.layers.MaxPooling1D(pool_size=2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(units=n2, activation='relu'),
        tf.keras.layers.Dense(units=n3, activation='relu'),
        tf.keras.layers.Dense(units=2)
    ])
    
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=patience,
        mode='min',
        restore_best_weights=True
    )
    
    conv_model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss=tf.keras.losses.MeanSquaredError(),
        metrics=[tf.keras.metrics.MeanSquaredError(), NSE, r_square]
    )
    
    conv_history = conv_model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=max_epochs,
        callbacks=[early_stopping]
    )
    
    return conv_model, conv_history

# %%
def create_train_lstm_model(X_train=X_train, y_train=Y_train, X_val=X_val, y_val=Y_val, max_epochs=20, patience=2,
                          n1=64, n2=64, n3=64, lr=0.001):
    if len(X_train.shape) == 2:
        X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    if len(X_val.shape) == 2:
        X_val = X_val.reshape((X_val.shape[0], 1, X_val.shape[1]))
            
    lstm_model = tf.keras.models.Sequential([
        tf.keras.layers.LSTM(n1, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True),
        tf.keras.layers.Flatten(),  # Add Flatten layer to handle dimension mismatch
        tf.keras.layers.Dense(units=n2, activation='relu'),
        tf.keras.layers.Dense(units=n3, activation='relu'),
        tf.keras.layers.Dense(units=2)
    ])
    
    # Define early stopping callback
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=patience,
        mode='min',
        restore_best_weights=True
    )
    
    # Compile the model
    lstm_model.compile(
        optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=lr),
        loss=tf.keras.losses.MeanSquaredError(),
        metrics=[tf.keras.metrics.MeanSquaredError(), NSE, r_square]
    )
    
    # Train the model
    lstm_history = lstm_model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=max_epochs,
        callbacks=[early_stopping]
    )
    
    return lstm_model, lstm_history

# %% [markdown]
# ## Training

# %%
dnn_model, dnn_history = create_train_dnn_model()
# Out:
# Epoch 1/20
# 119/119 [==============================] - 5s 13ms/step - loss: 1025078.7500 - mean_squared_error: 1025078.7500 - NSE: -12000.7744 - r_square: 0.0470 - val_loss: 433.2422 - val_mean_squared_error: 433.2422 - val_NSE: -4.0429 - val_r_square: 0.0274
# Epoch 2/20
# 119/119 [==============================] - 1s 8ms/step - loss: 224.3783 - mean_squared_error: 224.3783 - NSE: -1.7184 - r_square: 0.0268 - val_loss: 124.7406 - val_mean_squared_error: 124.7406 - val_NSE: -0.4690 - val_r_square: 0.0575
# Epoch 3/20
# 119/119 [==============================] - 1s 8ms/step - loss: 910.6548 - mean_squared_error: 910.6548 - NSE: -10.1034 - r_square: 0.0308 - val_loss: 1295.3782 - val_mean_squared_error: 1295.3782 - val_NSE: -13.9965 - val_r_square: 0.0274
# Epoch 4/20
# 119/119 [==============================] - 1s 8ms/step - loss: 25419.1992 - mean_squared_error: 25419.1992 - NSE: -302.5604 - r_square: 0.0212 - val_loss: 409.2370 - val_mean_squared_error: 409.2370 - val_NSE: -3.7223 - val_r_square: 0.0127

# %%
cnn_model, cnn_history = create_train_cnn_model()
# Out:
# Epoch 1/20
# 119/119 [==============================] - 4s 13ms/step - loss: 10008211.0000 - mean_squared_error: 10008211.0000 - NSE: -116296.6719 - r_square: 0.1123 - val_loss: 12580.4863 - val_mean_squared_error: 12580.4863 - val_NSE: -143.9435 - val_r_square: 0.0901
# Epoch 2/20
# 119/119 [==============================] - 1s 8ms/step - loss: 763.1125 - mean_squared_error: 763.1125 - NSE: -8.1600 - r_square: 0.0946 - val_loss: 163.5598 - val_mean_squared_error: 163.5598 - val_NSE: -0.8980 - val_r_square: 0.0517
# Epoch 3/20
# 119/119 [==============================] - 1s 8ms/step - loss: 257.0747 - mean_squared_error: 257.0747 - NSE: -2.1481 - r_square: 0.0321 - val_loss: 83.5959 - val_mean_squared_error: 83.5959 - val_NSE: 0.0349 - val_r_square: 0.0846
# Epoch 4/20
# 119/119 [==============================] - 1s 9ms/step - loss: 114.5993 - mean_squared_error: 114.5993 - NSE: -0.3923 - r_square: 0.0300 - val_loss: 53.8472 - val_mean_squared_error: 53.8472 - val_NSE: 0.3822 - val_r_square: 0.0279
# Epoch 5/20
# 119/119 [==============================] - 1s 8ms/step - loss: 14140.7715 - mean_squared_error: 14140.7715 - NSE: -173.0654 - r_square: 0.0314 - val_loss: 4111.2876 - val_mean_squared_error: 4111.2876 - val_NSE: -46.3361 - val_r_square: 0.0840
# Epoch 6/20
# 119/119 [==============================] - 1s 8ms/step - loss: 554.9915 - mean_squared_error: 554.9915 - NSE: -5.6831 - r_square: 0.0905 - val_loss: 75.4587 - val_mean_squared_error: 75.4587 - val_NSE: 0.1314 - val_r_square: 0.0803

# %%
# Train the model
lstm_model, lstm_history = create_train_lstm_model()
# Out:
# Epoch 1/20
# 119/119 [==============================] - 8s 24ms/step - loss: 45.0705 - mean_squared_error: 45.0705 - NSE: 0.4595 - r_square: 0.1658 - val_loss: 8.8672 - val_mean_squared_error: 8.8672 - val_NSE: 0.8983 - val_r_square: 0.4188
# Epoch 2/20
# 119/119 [==============================] - 1s 10ms/step - loss: 8.3618 - mean_squared_error: 8.3618 - NSE: 0.8985 - r_square: 0.2757 - val_loss: 8.4594 - val_mean_squared_error: 8.4594 - val_NSE: 0.9027 - val_r_square: 0.2834
# Epoch 3/20
# 119/119 [==============================] - 1s 11ms/step - loss: 6.9612 - mean_squared_error: 6.9612 - NSE: 0.9145 - r_square: 0.3599 - val_loss: 7.2893 - val_mean_squared_error: 7.2893 - val_NSE: 0.9161 - val_r_square: 0.3720
# Epoch 4/20
# 119/119 [==============================] - 1s 10ms/step - loss: 5.8281 - mean_squared_error: 5.8281 - NSE: 0.9288 - r_square: 0.4433 - val_loss: 6.6147 - val_mean_squared_error: 6.6147 - val_NSE: 0.9234 - val_r_square: 0.4002
# Epoch 5/20
# 119/119 [==============================] - 1s 10ms/step - loss: 5.5287 - mean_squared_error: 5.5287 - NSE: 0.9322 - r_square: 0.4689 - val_loss: 6.4278 - val_mean_squared_error: 6.4278 - val_NSE: 0.9254 - val_r_square: 0.4078
# Epoch 6/20
# 119/119 [==============================] - 1s 10ms/step - loss: 5.3672 - mean_squared_error: 5.3672 - NSE: 0.9343 - r_square: 0.4750 - val_loss: 6.5507 - val_mean_squared_error: 6.5507 - val_NSE: 0.9241 - val_r_square: 0.4074
# Epoch 7/20
# 119/119 [==============================] - 1s 10ms/step - loss: 5.3741 - mean_squared_error: 5.3741 - NSE: 0.9341 - r_square: 0.4745 - val_loss: 6.5681 - val_mean_squared_error: 6.5681 - val_NSE: 0.9239 - val_r_square: 0.4074

# %% [markdown]
# ## Predictions

# %%
np.set_printoptions(suppress=True)

# %%
test_df
# Out:
#      Unnamed: 0             datetime  month  day  hour         t    Station  \
# 0         31344  2017-10-16 00:00:00     10   16     0       0.0  Montalban
# 1         31345  2017-10-16 00:00:00     10   16     0       0.0   Sto_Nino
# 2         31346  2017-10-16 01:00:00     10   16     1    3600.0  Montalban
# 3         31347  2017-10-16 01:00:00     10   16     1    3600.0   Sto_Nino
# 4         31348  2017-10-16 02:00:00     10   16     2    7200.0  Montalban
# ..          ...                  ...    ...  ...   ...       ...        ...
# 235       20155  2017-02-24 21:00:00      2   24    21  421200.0   Sto_Nino
# 236       20156  2017-02-24 22:00:00      2   24    22  424800.0  Montalban
# 237       20157  2017-02-24 22:00:00      2   24    22  424800.0   Sto_Nino
# 238       20158  2017-02-24 23:00:00      2   24    23  428400.0  Montalban
# 239       20159  2017-02-24 23:00:00      2   24    23  428400.0   Sto_Nino
#
#          x  Rainfall_Aries  Rainfall_Boso  Rainfall_Campana  Rainfall_Nangka  \
# 0        0               0              0                 0                0
# 1    14420               0              0                 0                0
# 2        0               0              0                 0                0
# 3    14420               0              0                 0                0
# 4        0               0              0                 0                0
# ..     ...             ...            ...               ...              ...
# 235  14420               0              0                 0                0
# 236      0               0              0                 0                0
# 237  14420               0              0                 0                0
# 238      0               0              0                 0                0
# 239  14420               0              0                 0                0
#
#      Rainfall_Oro  Waterlevel  Discharge  Cross_Section  Velocity  fric_coeff  \
# 0               0       21.67  27.926745         650.10  0.042958       0.035
# 1               0       12.74  38.902552         840.84  0.046266       0.033
# 2               0       21.66  27.653933         649.80  0.042558       0.035
# 3               0       12.71  37.710339         838.86  0.044954       0.033
# 4               0       21.66  27.653933         649.80  0.042558       0.035
# ..            ...         ...        ...            ...       ...         ...
# 235             0       11.82  13.565535         780.12  0.017389       0.033
# 236             0       20.95  13.707290         628.50  0.021810       0.035
# 237             0       11.82  13.565535         780.12  0.017389       0.033
# 238             0       20.95  13.707290         628.50  0.021810       0.035
# 239             0       11.82  13.565535         780.12  0.017389       0.033
#
#         slope
# 0    0.002000
# 1    0.000667
# 2    0.002000
# 3    0.000667
# 4    0.002000
# ..        ...
# 235  0.000667
# 236  0.002000
# 237  0.000667
# 238  0.002000
# 239  0.000667
#
# [1536 rows x 19 columns]

# %%
X_test
# Out:
# array([[     0.        ,      0.        ,      0.        , ...,
#              0.        ,      0.035     ,      0.002     ],
#        [     0.        ,      0.        ,      0.        , ...,
#              0.        ,      0.033     ,      0.00066667],
#        [     0.        ,      0.        ,      0.        , ...,
#           3600.        ,      0.035     ,      0.002     ],
#        ...,
#        [     0.        ,      0.        ,      0.        , ...,
#         424800.        ,      0.033     ,      0.00066667],
#        [     0.        ,      0.        ,      0.        , ...,
#         428400.        ,      0.035     ,      0.002     ],
#        [     0.        ,      0.        ,      0.        , ...,
#         428400.        ,      0.033     ,      0.00066667]])

# %%
X_test.shape
# Out:
# (1536, 9)

# %%
X_test_lstm = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

X_test_lstm
# Out:
# array([[[     0.        ,      0.        ,      0.        , ...,
#               0.        ,      0.035     ,      0.002     ]],
#
#        [[     0.        ,      0.        ,      0.        , ...,
#               0.        ,      0.033     ,      0.00066667]],
#
#        [[     0.        ,      0.        ,      0.        , ...,
#            3600.        ,      0.035     ,      0.002     ]],
#
#        ...,
#
#        [[     0.        ,      0.        ,      0.        , ...,
#          424800.        ,      0.033     ,      0.00066667]],
#
#        [[     0.        ,      0.        ,      0.        , ...,
#          428400.        ,      0.035     ,      0.002     ]],
#
#        [[     0.        ,      0.        ,      0.        , ...,
#          428400.        ,      0.033     ,      0.00066667]]])

# %%
# (batch size, time steps, features)
X_test_lstm.shape
# Out:
# (1536, 1, 9)

# %%
# LSTM predictions

lstm_predictions_without_window_all_variables = lstm_model(X_test_lstm)

# %%
lstm_predictions_without_window_all_variables
# Out:
# <tf.Tensor: shape=(1536, 2), dtype=float32, numpy=
# array([[ 0.09839234, 19.51      ],
#        [ 0.18142524, 11.833735  ],
#        [ 0.07077333, 19.10762   ],
#        ...,
#        [ 0.07077915, 19.107618  ],
#        [ 0.07077915, 19.107618  ],
#        [ 0.07077915, 19.107618  ]], dtype=float32)>

# %%
y_pred_h = lstm_predictions_without_window_all_variables[:,1]
y_pred_v = lstm_predictions_without_window_all_variables[:,0]

# %%
y_pred_h
# Out:
# <tf.Tensor: shape=(1536,), dtype=float32, numpy=
# array([19.51    , 11.833735, 19.10762 , ..., 19.107618, 19.107618,
#        19.107618], dtype=float32)>

# %%
y_pred_v
# Out:
# <tf.Tensor: shape=(1536,), dtype=float32, numpy=
# array([0.09839234, 0.18142524, 0.07077333, ..., 0.07077915, 0.07077915,
#        0.07077915], dtype=float32)>

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(y_pred_h)

# %%
plt.plot(y_pred_v)

# %% [markdown]
# --- Stop ---

# %%
Y_test_2016_2017
# Out:
# array([[ 0.01888235, 11.89      ],
#        [ 0.01844587, 11.87      ],
#        [ 0.0180173 , 11.85      ],
#        ...,
#        [ 0.03440052, 12.44      ],
#        [ 0.03440052, 12.44      ],
#        [ 0.03440052, 12.44      ]])

# %%
y_true_h = Y_test_2016_2017[:,1]
y_true_v = Y_test_2016_2017[:,0]

# %%
y_true_h
# Out:
# array([11.89, 11.87, 11.85, ..., 12.44, 12.44, 12.44])

# %%
y_true_v
# Out:
# array([0.01888235, 0.01844587, 0.0180173 , ..., 0.03440052, 0.03440052,
#        0.03440052])

# %%
n = len(Y_test_2016_2017)
mse_h = np.mean(np.square(y_true_h - y_pred_h))
mse_v = np.mean(np.square(y_true_v - y_pred_v))

mse_h, mse_v
# Out:
# (0.42879322, 0.0028713248)

# %%
(mse_h + mse_v)/2
# Out:
# 0.21583227813243866

# %%
SS_res_h = np.sum(np.square(y_true_h - y_pred_h)) 
SS_tot_h = np.sum(np.square(y_true_h - np.mean(y_true_h)))

NSE_h = 1 - SS_res_h/(SS_tot_h)
NSE_h
# Out:
# -0.38106958070518515

# %%
SS_res_v = np.sum(np.square(y_true_v - y_pred_v)) 
SS_tot_v = np.sum(np.square(y_true_v - np.mean(y_true_v)))

NSE_v = 1 - SS_res_v/(SS_tot_v)
NSE_v
# Out:
# -0.7006108458891884
