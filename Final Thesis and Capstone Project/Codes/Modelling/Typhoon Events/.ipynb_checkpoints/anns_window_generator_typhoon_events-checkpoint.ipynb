# %%
import tensorflow as tf
import pandas as pd
import os
import numpy as np
import datetime as dt
from random import seed
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import backend as K
tf.compat.v1.experimental.output_all_intermediates(True)

# %%
tf.random.set_seed(36)

# %% [markdown]
# ## Dataset

# %%
BASE_DIR_PATH = '../Datasets/typhoons'
TRAIN_PATH = os.path.join(BASE_DIR_PATH, 'train')
VAL_PATH = os.path.join(BASE_DIR_PATH, 'val')
TEST_PATH = os.path.join(BASE_DIR_PATH, 'test')

# %%
def load_files(df_list, file_path):
    '''
    Loading the files from file_path into a list called df_list as pandas DataFrames
    '''
    file_names = os.listdir(file_path)
    print(file_names)
    
    for file in file_names:
        tmp = pd.read_csv(os.path.join(file_path, file))
        df_list.append(tmp)

# %%
train_data = []
val_data = []
test_data = []

load_files(train_data, TRAIN_PATH)
load_files(val_data, VAL_PATH)
load_files(test_data, TEST_PATH)
# Out:
# ['ambo_2016.csv', 'auring_2017.csv', 'bising_2017.csv', 'butchoy_2016.csv', 'carina_2016.csv', 'crising_2017.csv', 'dante_2017.csv', 'dindo_2016.csv', 'emong_2017.csv', 'enteng_2016.csv', 'fabian_2017.csv', 'ferdie_2016.csv', 'gener_2016.csv', 'helen_2016.csv', 'igme_2016.csv', 'julian_2016.csv', 'karen_2016.csv', 'lawin_2016.csv', 'marce_2016.csv', 'nina_2016.csv']
# ['gorio_2017.csv', 'isang_2017.csv', 'jolina_2017.csv', 'kiko_2017.csv', 'lannie_2017.csv', 'nando_2017.csv', 'odette_2017.csv']
# ['paolo_2017.csv', 'quedan_2017.csv', 'ramil_2017.csv', 'salome_2017.csv', 'tino_2017.csv', 'urduja_2017.csv', 'vinta_2017.csv']

# %%
train_data[0]
# Out:
#      Unnamed: 0             datetime  month  day  hour         t    Station  \
# 0          8448  2016-06-26 00:00:00      6   26     0       0.0  Montalban
# 1          8449  2016-06-26 00:00:00      6   26     0       0.0   Sto_Nino
# 2          8450  2016-06-26 01:00:00      6   26     1    3600.0  Montalban
# 3          8451  2016-06-26 01:00:00      6   26     1    3600.0   Sto_Nino
# 4          8452  2016-06-26 02:00:00      6   26     2    7200.0  Montalban
# ..          ...                  ...    ...  ...   ...       ...        ...
# 139        8587  2016-06-28 21:00:00      6   28    21  248400.0   Sto_Nino
# 140        8588  2016-06-28 22:00:00      6   28    22  252000.0  Montalban
# 141        8589  2016-06-28 22:00:00      6   28    22  252000.0   Sto_Nino
# 142        8590  2016-06-28 23:00:00      6   28    23  255600.0  Montalban
# 143        8591  2016-06-28 23:00:00      6   28    23  255600.0   Sto_Nino
#
#          x  Rainfall_Aries  Rainfall_Boso  Rainfall_Campana  Rainfall_Nangka  \
# 0        0               0              0                 0                0
# 1    14420               0              0                 0                0
# 2        0               0              0                 0                0
# 3    14420               0              0                 0                0
# 4        0               0              0                 0                0
# ..     ...             ...            ...               ...              ...
# 139  14420               0              0                 0                0
# 140      0               0              0                 0                0
# 141  14420               0              0                 0                0
# 142      0               0              0                 0                0
# 143  14420               0              0                 0                0
#
#      Rainfall_Oro  Waterlevel  Discharge  Cross_Section  Velocity  fric_coeff  \
# 0               0       20.52   8.918747         615.60  0.014488       0.035
# 1               0       11.95  15.963477         788.70  0.020240       0.033
# 2               0       20.52   8.918747         615.60  0.014488       0.035
# 3               0       11.95  15.963477         788.70  0.020240       0.033
# 4               0       20.51   8.829671         615.30  0.014350       0.035
# ..            ...         ...        ...            ...       ...         ...
# 139             0       11.97  16.360817         790.02  0.020709       0.033
# 140             0       20.53   9.008703         615.90  0.014627       0.035
# 141             0       11.97  16.360817         790.02  0.020709       0.033
# 142             0       20.53   9.008703         615.90  0.014627       0.035
# 143             0       11.97  16.360817         790.02  0.020709       0.033
#
#         slope
# 0    0.002000
# 1    0.000667
# 2    0.002000
# 3    0.000667
# 4    0.002000
# ..        ...
# 139  0.000667
# 140  0.002000
# 141  0.000667
# 142  0.002000
# 143  0.000667
#
# [144 rows x 19 columns]

# %%
def get_cols(df_list):
    '''
    Get relevant columns for each DataFrame in df_list
    '''
    for i, df in enumerate(df_list):
        df = df[[
            'x', 
            't', 
            'fric_coeff', 
            'slope', 
            'Rainfall_Aries', 
            'Rainfall_Boso', 
            'Rainfall_Campana', 
            'Rainfall_Nangka', 
            'Rainfall_Oro', 
            'Waterlevel', 
            'Velocity'
        ]]
        
        df_list[i] = df

# %%
get_cols(train_data)
get_cols(val_data)
get_cols(test_data)

# %%
train_data[0]
# Out:
#          x         t  fric_coeff     slope  Rainfall_Aries  Rainfall_Boso  \
# 0        0       0.0       0.035  0.002000               0              0
# 1    14420       0.0       0.033  0.000667               0              0
# 2        0    3600.0       0.035  0.002000               0              0
# 3    14420    3600.0       0.033  0.000667               0              0
# 4        0    7200.0       0.035  0.002000               0              0
# ..     ...       ...         ...       ...             ...            ...
# 139  14420  248400.0       0.033  0.000667               0              0
# 140      0  252000.0       0.035  0.002000               0              0
# 141  14420  252000.0       0.033  0.000667               0              0
# 142      0  255600.0       0.035  0.002000               0              0
# 143  14420  255600.0       0.033  0.000667               0              0
#
#      Rainfall_Campana  Rainfall_Nangka  Rainfall_Oro  Waterlevel  Velocity
# 0                   0                0             0       20.52  0.014488
# 1                   0                0             0       11.95  0.020240
# 2                   0                0             0       20.52  0.014488
# 3                   0                0             0       11.95  0.020240
# 4                   0                0             0       20.51  0.014350
# ..                ...              ...           ...         ...       ...
# 139                 0                0             0       11.97  0.020709
# 140                 0                0             0       20.53  0.014627
# 141                 0                0             0       11.97  0.020709
# 142                 0                0             0       20.53  0.014627
# 143                 0                0             0       11.97  0.020709
#
# [144 rows x 11 columns]

# %% [markdown]
# ## Window Generator

# %%
sto_nino_train = []
sto_nino_val = []
sto_nino_test = []

montalban_train = []
montalban_val = []
montalban_test = []

# %%
def get_station_data(df_list, sto_nino_data, montalban_data):
    '''
    Get data from Sto. Nino and Montalban station from DataFrames in df_list and store it in station_data
    '''
    for df in df_list:
        tmp_s = df[df['x'] == 14420]
        sto_nino_data.append(tmp_s)
        
        tmp_m = df[df['x'] == 0]
        montalban_data.append(tmp_m)

# %%
get_station_data(train_data, sto_nino_train, montalban_train)
get_station_data(val_data, sto_nino_val, montalban_val)
get_station_data(test_data, sto_nino_test, montalban_test)

# %%
sto_nino_train[0]
# Out:
#          x         t  fric_coeff     slope  Rainfall_Aries  Rainfall_Boso  \
# 1    14420       0.0       0.033  0.000667               0              0
# 3    14420    3600.0       0.033  0.000667               0              0
# 5    14420    7200.0       0.033  0.000667               0              0
# 7    14420   10800.0       0.033  0.000667               0              0
# 9    14420   14400.0       0.033  0.000667               0              0
# ..     ...       ...         ...       ...             ...            ...
# 135  14420  241200.0       0.033  0.000667               0              0
# 137  14420  244800.0       0.033  0.000667               0              0
# 139  14420  248400.0       0.033  0.000667               0              0
# 141  14420  252000.0       0.033  0.000667               0              0
# 143  14420  255600.0       0.033  0.000667               0              0
#
#      Rainfall_Campana  Rainfall_Nangka  Rainfall_Oro  Waterlevel  Velocity
# 1                   0                0             0       11.95  0.020240
# 3                   0                0             0       11.95  0.020240
# 5                   0                0             0       11.94  0.020009
# 7                   0                0             0       11.94  0.020009
# 9                   0                0             0       11.93  0.019779
# ..                ...              ...           ...         ...       ...
# 135                 0                0             0       11.98  0.020947
# 137                 0                0             0       11.98  0.020947
# 139                 0                0             0       11.97  0.020709
# 141                 0                0             0       11.97  0.020709
# 143                 0                0             0       11.97  0.020709
#
# [72 rows x 11 columns]

# %%
montalban_train[0]
# Out:
#      x         t  fric_coeff  slope  Rainfall_Aries  Rainfall_Boso  \
# 0    0       0.0       0.035  0.002               0              0
# 2    0    3600.0       0.035  0.002               0              0
# 4    0    7200.0       0.035  0.002               0              0
# 6    0   10800.0       0.035  0.002               0              0
# 8    0   14400.0       0.035  0.002               0              0
# ..  ..       ...         ...    ...             ...            ...
# 134  0  241200.0       0.035  0.002               0              0
# 136  0  244800.0       0.035  0.002               0              0
# 138  0  248400.0       0.035  0.002               0              0
# 140  0  252000.0       0.035  0.002               0              0
# 142  0  255600.0       0.035  0.002               0              0
#
#      Rainfall_Campana  Rainfall_Nangka  Rainfall_Oro  Waterlevel  Velocity
# 0                   0                0             0       20.52  0.014488
# 2                   0                0             0       20.52  0.014488
# 4                   0                0             0       20.51  0.014350
# 6                   0                0             0       20.51  0.014350
# 8                   0                0             0       20.51  0.014350
# ..                ...              ...           ...         ...       ...
# 134                 0                0             0       20.53  0.014627
# 136                 0                0             0       20.53  0.014627
# 138                 0                0             0       20.53  0.014627
# 140                 0                0             0       20.53  0.014627
# 142                 0                0             0       20.53  0.014627
#
# [72 rows x 11 columns]

# %%
class WindowGenerator():
    def __init__(self, input_width, label_width, shift, df, shuffle=True, label_columns=None):
        # Store the raw data.
        self.df = df

        # Work out the label column indices.
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(df.columns)}

        # Work out the window parameters.
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift

        self.total_window_size = input_width + shift

        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]

        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
        
        self.shuffle = shuffle

    def __repr__(self):
        return '\n'.join([
            f'Total window size: {self.total_window_size}',
            f'Input indices: {self.input_indices}',
            f'Label indices: {self.label_indices}',
            f'Label column name(s): {self.label_columns}'])

    def split_window(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack([labels[:, :, self.column_indices[name]] for name in self.label_columns], axis=-1)

        # Slicing doesn't preserve static shape information, so set the shapes
        # manually. This way the `tf.data.Datasets` are easier to inspect.
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])

        return inputs, labels
    
    # Creating tf datasets for more convenient use and integration into model in the future
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.utils.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=self.shuffle,
            batch_size=32,)

        ds = ds.map(self.split_window)

        return ds
    
    # properties to access them as tf datasets
    @property
    def ds(self):
        return self.make_dataset(self.df)

    @property
    def example(self):
        """Get and cache an example batch of `inputs, labels` for plotting."""
        result = getattr(self, '_example', None)
        if result is None:
            # No example batch was found, so get one from the `.train` dataset
            result = next(iter(self.ds))
            # And cache it for next time
            self._example = result
        return result

# %%
sample = WindowGenerator(
        input_width=6, label_width=6, shift=1,
        df = sto_nino_train[0],
        label_columns=['Waterlevel', 'Velocity']
    )

sample
# Out:
# Total window size: 7
# Input indices: [0 1 2 3 4 5]
# Label indices: [1 2 3 4 5 6]
# Label column name(s): ['Waterlevel', 'Velocity']

# %%
sample.example
# Out:
# (<tf.Tensor: shape=(32, 6, 11), dtype=float32, numpy=
#  array([[[1.4420000e+04, 5.4000000e+04, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2350000e+01, 3.1350050e-02],
#          [1.4420000e+04, 5.7600000e+04, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2330000e+01, 3.0701710e-02],
#          [1.4420000e+04, 6.1200000e+04, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2330000e+01, 3.0701710e-02],
#          [1.4420000e+04, 6.4800000e+04, 3.3000000e-02, ...,
#           1.0000000e+00, 1.2330000e+01, 3.0701710e-02],
#          [1.4420000e+04, 6.8400000e+04, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2310000e+01, 3.0063845e-02],
#          [1.4420000e+04, 7.2000000e+04, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2380000e+01, 3.2342475e-02]],
#
#         [[1.4420000e+04, 1.4760000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2090000e+01, 2.3704911e-02],
#          [1.4420000e+04, 1.5120000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2080000e+01, 2.3443123e-02],
#          [1.4420000e+04, 1.5480000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2070000e+01, 2.3183592e-02],
#          [1.4420000e+04, 1.5840000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2060000e+01, 2.2926304e-02],
#          [1.4420000e+04, 1.6200000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2050000e+01, 2.2671245e-02],
#          [1.4420000e+04, 1.6560000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2040000e+01, 2.2418400e-02]],
#
#         [[1.4420000e+04, 1.9440000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.1990000e+01, 2.1186929e-02],
#          [1.4420000e+04, 1.9800000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.1990000e+01, 2.1186929e-02],
#          [1.4420000e+04, 2.0160000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.1990000e+01, 2.1186929e-02],
#          [1.4420000e+04, 2.0520000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.1990000e+01, 2.1186929e-02],
#          [1.4420000e+04, 2.0880000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.1990000e+01, 2.1186929e-02],
#          [1.4420000e+04, 2.1240000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.1990000e+01, 2.1186929e-02]],
#
#         ...,
#
#         [[1.4420000e+04, 1.0800000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2070000e+01, 2.3183592e-02],
#          [1.4420000e+04, 1.1160000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2080000e+01, 2.3443123e-02],
#          [1.4420000e+04, 1.1520000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2060000e+01, 2.2926304e-02],
#          [1.4420000e+04, 1.1880000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2050000e+01, 2.2671245e-02],
#          [1.4420000e+04, 1.2240000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2050000e+01, 2.2671245e-02],
#          [1.4420000e+04, 1.2600000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2040000e+01, 2.2418400e-02]],
#
#         [[1.4420000e+04, 9.3600000e+04, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2160000e+01, 2.5601786e-02],
#          [1.4420000e+04, 9.7200000e+04, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2140000e+01, 2.5048187e-02],
#          [1.4420000e+04, 1.0080000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2120000e+01, 2.4503954e-02],
#          [1.4420000e+04, 1.0440000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2100000e+01, 2.3968969e-02],
#          [1.4420000e+04, 1.0800000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2070000e+01, 2.3183592e-02],
#          [1.4420000e+04, 1.1160000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2080000e+01, 2.3443123e-02]],
#
#         [[1.4420000e+04, 1.5480000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2070000e+01, 2.3183592e-02],
#          [1.4420000e+04, 1.5840000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2060000e+01, 2.2926304e-02],
#          [1.4420000e+04, 1.6200000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2050000e+01, 2.2671245e-02],
#          [1.4420000e+04, 1.6560000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2040000e+01, 2.2418400e-02],
#          [1.4420000e+04, 1.6920000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2040000e+01, 2.2418400e-02],
#          [1.4420000e+04, 1.7280000e+05, 3.3000000e-02, ...,
#           0.0000000e+00, 1.2030000e+01, 2.2167757e-02]]], dtype=float32)>,
#  <tf.Tensor: shape=(32, 6, 2), dtype=float32, numpy=
#  array([[[12.33      ,  0.03070171],
#          [12.33      ,  0.03070171],
#          [12.33      ,  0.03070171],
#          [12.31      ,  0.03006385],
#          [12.38      ,  0.03234247],
#          [12.26      ,  0.02851423]],
#
#         [[12.08      ,  0.02344312],
#          [12.07      ,  0.02318359],
#          [12.06      ,  0.0229263 ],
#          [12.05      ,  0.02267125],
#          [12.04      ,  0.0224184 ],
#          [12.04      ,  0.0224184 ]],
#
#         [[11.99      ,  0.02118693],
#          [11.99      ,  0.02118693],
#          [11.99      ,  0.02118693],
#          [11.99      ,  0.02118693],
#          [11.99      ,  0.02118693],
#          [11.99      ,  0.02118693]],
#
#         [[11.99      ,  0.02118693],
#          [11.99      ,  0.02118693],
#          [11.99      ,  0.02118693],
#          [11.98      ,  0.02094709],
#          [11.98      ,  0.02094709],
#          [11.99      ,  0.02118693]],
#
#         [[11.98      ,  0.02094709],
#          [11.98      ,  0.02094709],
#          [11.98      ,  0.02094709],
#          [11.97      ,  0.02070937],
#          [11.97      ,  0.02070937],
#          [11.97      ,  0.02070937]],
#
#         [[12.1       ,  0.02396897],
#          [12.09      ,  0.02370491],
#          [12.08      ,  0.02344312],
#          [12.07      ,  0.02318359],
#          [12.06      ,  0.0229263 ],
#          [12.05      ,  0.02267125]],
#
#         [[12.06      ,  0.0229263 ],
#          [12.05      ,  0.02267125],
#          [12.05      ,  0.02267125],
#          [12.04      ,  0.0224184 ],
#          [12.04      ,  0.0224184 ],
#          [12.08      ,  0.02344312]],
#
#         [[12.37      ,  0.03200899],
#          [12.35      ,  0.03135005],
#          [12.33      ,  0.03070171],
#          [12.33      ,  0.03070171],
#          [12.33      ,  0.03070171],
#          [12.31      ,  0.03006385]],
#
#         [[12.11      ,  0.02423531],
#          [12.33      ,  0.03070171],
#          [12.37      ,  0.03200899],
#          [12.35      ,  0.03135005],
#          [12.33      ,  0.03070171],
#          [12.33      ,  0.03070171]],
#
#         [[11.93      ,  0.01977943],
#          [11.92      ,  0.01955211],
#          [11.92      ,  0.01955211],
#          [11.92      ,  0.01955211],
#          [11.92      ,  0.01955211],
#          [11.92      ,  0.01955211]],
#
#         [[12.05      ,  0.02267125],
#          [12.04      ,  0.0224184 ],
#          [12.04      ,  0.0224184 ],
#          [12.08      ,  0.02344312],
#          [12.11      ,  0.02423531],
#          [12.11      ,  0.02423531]],
#
#         [[11.99      ,  0.02118693],
#          [11.99      ,  0.02118693],
#          [11.99      ,  0.02118693],
#          [11.99      ,  0.02118693],
#          [11.99      ,  0.02118693],
#          [11.99      ,  0.02118693]],
#
#         [[12.07      ,  0.02318359],
#          [12.06      ,  0.0229263 ],
#          [12.05      ,  0.02267125],
#          [12.04      ,  0.0224184 ],
#          [12.04      ,  0.0224184 ],
#          [12.03      ,  0.02216776]],
#
#         [[11.92      ,  0.01955211],
#          [11.92      ,  0.01955211],
#          [11.92      ,  0.01955211],
#          [12.11      ,  0.02423531],
#          [12.33      ,  0.03070171],
#          [12.37      ,  0.03200899]],
#
#         [[12.04      ,  0.0224184 ],
#          [12.03      ,  0.02216776],
#          [12.02      ,  0.0219193 ],
#          [12.02      ,  0.0219193 ],
#          [12.01      ,  0.02167302],
#          [12.        ,  0.0214289 ]],
#
#         [[11.94      ,  0.0200088 ],
#          [11.93      ,  0.01977943],
#          [11.93      ,  0.01977943],
#          [11.92      ,  0.01955211],
#          [11.92      ,  0.01955211],
#          [11.92      ,  0.01955211]],
#
#         [[12.12      ,  0.02450395],
#          [12.1       ,  0.02396897],
#          [12.07      ,  0.02318359],
#          [12.08      ,  0.02344312],
#          [12.06      ,  0.0229263 ],
#          [12.05      ,  0.02267125]],
#
#         [[12.11      ,  0.02423531],
#          [12.1       ,  0.02396897],
#          [12.09      ,  0.02370491],
#          [12.08      ,  0.02344312],
#          [12.07      ,  0.02318359],
#          [12.06      ,  0.0229263 ]],
#
#         [[12.16      ,  0.02560179],
#          [12.14      ,  0.02504819],
#          [12.12      ,  0.02450395],
#          [12.1       ,  0.02396897],
#          [12.07      ,  0.02318359],
#          [12.08      ,  0.02344312]],
#
#         [[11.92      ,  0.01955211],
#          [11.92      ,  0.01955211],
#          [11.92      ,  0.01955211],
#          [11.92      ,  0.01955211],
#          [12.11      ,  0.02423531],
#          [12.33      ,  0.03070171]],
#
#         [[11.99      ,  0.02118693],
#          [11.98      ,  0.02094709],
#          [11.98      ,  0.02094709],
#          [11.99      ,  0.02118693],
#          [11.99      ,  0.02118693],
#          [11.98      ,  0.02094709]],
#
#         [[12.35      ,  0.03135005],
#          [12.33      ,  0.03070171],
#          [12.33      ,  0.03070171],
#          [12.33      ,  0.03070171],
#          [12.31      ,  0.03006385],
#          [12.38      ,  0.03234247]],
#
#         [[11.92      ,  0.01955211],
#          [11.92      ,  0.01955211],
#          [11.92      ,  0.01955211],
#          [11.92      ,  0.01955211],
#          [11.92      ,  0.01955211],
#          [12.11      ,  0.02423531]],
#
#         [[12.01      ,  0.02167302],
#          [12.        ,  0.0214289 ],
#          [11.99      ,  0.02118693],
#          [11.99      ,  0.02118693],
#          [11.99      ,  0.02118693],
#          [11.99      ,  0.02118693]],
#
#         [[12.        ,  0.0214289 ],
#          [11.99      ,  0.02118693],
#          [11.99      ,  0.02118693],
#          [11.99      ,  0.02118693],
#          [11.99      ,  0.02118693],
#          [11.99      ,  0.02118693]],
#
#         [[12.33      ,  0.03070171],
#          [12.37      ,  0.03200899],
#          [12.35      ,  0.03135005],
#          [12.33      ,  0.03070171],
#          [12.33      ,  0.03070171],
#          [12.33      ,  0.03070171]],
#
#         [[12.33      ,  0.03070171],
#          [12.33      ,  0.03070171],
#          [12.31      ,  0.03006385],
#          [12.38      ,  0.03234247],
#          [12.26      ,  0.02851423],
#          [12.25      ,  0.02821192]],
#
#         [[12.02      ,  0.0219193 ],
#          [12.01      ,  0.02167302],
#          [12.        ,  0.0214289 ],
#          [11.99      ,  0.02118693],
#          [11.99      ,  0.02118693],
#          [11.99      ,  0.02118693]],
#
#         [[11.94      ,  0.0200088 ],
#          [11.94      ,  0.0200088 ],
#          [11.93      ,  0.01977943],
#          [11.93      ,  0.01977943],
#          [11.92      ,  0.01955211],
#          [11.92      ,  0.01955211]],
#
#         [[12.08      ,  0.02344312],
#          [12.06      ,  0.0229263 ],
#          [12.05      ,  0.02267125],
#          [12.05      ,  0.02267125],
#          [12.04      ,  0.0224184 ],
#          [12.04      ,  0.0224184 ]],
#
#         [[12.14      ,  0.02504819],
#          [12.12      ,  0.02450395],
#          [12.1       ,  0.02396897],
#          [12.07      ,  0.02318359],
#          [12.08      ,  0.02344312],
#          [12.06      ,  0.0229263 ]],
#
#         [[12.06      ,  0.0229263 ],
#          [12.05      ,  0.02267125],
#          [12.04      ,  0.0224184 ],
#          [12.04      ,  0.0224184 ],
#          [12.03      ,  0.02216776],
#          [12.02      ,  0.0219193 ]]], dtype=float32)>)

# %%
sample.ds
# Out:
# <_MapDataset element_spec=(TensorSpec(shape=(None, 6, 11), dtype=tf.float32, name=None), TensorSpec(shape=(None, 6, 2), dtype=tf.float32, name=None))>

# %%
def generate_datasets(df_list, is_test=False):
    ds = None
    
    if not is_test:
        for i, df in enumerate(df_list):
            window = WindowGenerator(
                input_width=6, label_width=6, shift=1,
                df=df,
                label_columns=['Waterlevel', 'Velocity']
            )

            if i == 0:            
                ds = window.ds
            else:
                ds = ds.concatenate(window.ds)
        
        ds = ds.shuffle(buffer_size=len(list(ds)))
        return ds
    else:
        ds = {}
        typhoons = os.listdir(TEST_PATH)
        typhoons = [x[:-4] for x in typhoons]
        
        for i, df in enumerate(df_list):
            window = WindowGenerator(
                input_width=6, label_width=6, shift=1,
                df=df, shuffle=not is_test,
                label_columns=['Waterlevel', 'Velocity']
            )
            
            ds[typhoons[i]] = window.ds
            
        return ds

# %%
sto_nino_train_ds = generate_datasets(sto_nino_train)
montalban_train_ds = generate_datasets(montalban_train)

sto_nino_val_ds = generate_datasets(sto_nino_val)
montalban_val_ds = generate_datasets(montalban_val)

sto_nino_test_ds = generate_datasets(sto_nino_test, True)
montalban_test_ds = generate_datasets(montalban_test, True)

# %%
train_ds = sto_nino_train_ds.concatenate(montalban_train_ds)
train_ds = train_ds.shuffle(buffer_size=len(list(train_ds)))

val_ds = sto_nino_val_ds.concatenate(montalban_val_ds)
val_ds = val_ds.shuffle(buffer_size=len(list(val_ds)))

# %% [markdown]
# ## Evaluation Metrics

# %%
def r_square(y_true, y_pred):
    x = y_true
    y = y_pred
    mx = K.mean(x, axis=0)
    my = K.mean(y, axis=0)
    xm, ym = x - mx, y - my
    r_num = K.square(K.sum(xm * ym))
    x_square_sum = K.sum(xm * xm)
    y_square_sum = K.sum(ym * ym)
    r_den = (x_square_sum * y_square_sum) + K.epsilon()
    
    r = r_num / r_den
    return r

# %%
def NSE(y_true, y_pred):
    '''
    This is the Nash-Sutcliffe Efficiency Coefficient
    '''
    y_pred = K.flatten(y_pred)
    y_true = K.flatten(y_true)

    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ## Training

# %%
# For easy compiling and fitting of different models
MAX_EPOCHS = 20

def compile_and_fit(model, train_data=train_ds, val_data=val_ds, patience=2, lr=0.001):
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', 
        patience=patience, 
        mode='min', 
        restore_best_weights=True # added this
    )

    model.compile(
        loss=tf.keras.losses.MeanSquaredError(), 
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr), 
        metrics=[tf.keras.metrics.MeanSquaredError(), NSE, r_square]
    )

    history = model.fit(
        train_data, 
        epochs=MAX_EPOCHS,
        validation_data=val_data,
        callbacks=[early_stopping]
    )

    return history

# %%
def create_dense_model(n1=64, n2=64, n3=64):
    dense = tf.keras.Sequential([
        tf.keras.layers.Dense(units=n1, activation='relu'),
        tf.keras.layers.Dense(units=n2, activation='relu'),
        tf.keras.layers.Dense(units=n3, activation='relu'),
        tf.keras.layers.Dense(units=2)
    ])
    
    return dense

# %%
def create_lstm_model(n1=64, n2=64, n3=64):
    lstm_model = tf.keras.models.Sequential([
        tf.keras.layers.LSTM(n1, return_sequences=True),
        tf.keras.layers.Dense(units=n2, activation='relu'),
        tf.keras.layers.Dense(units=n3, activation='relu'),
        tf.keras.layers.Dense(units=2)
    ])
    
    return lstm_model

# %%
dense_model = create_dense_model()
dense_history = compile_and_fit(dense_model)
# Out:
# Epoch 1/20
# 132/132 [==============================] - 10s 25ms/step - loss: 19260956.0000 - mean_squared_error: 19260958.0000 - NSE: -311830.7188 - r_square: 0.1353 - val_loss: 5487.5415 - val_mean_squared_error: 5487.5415 - val_NSE: -119.5255 - val_r_square: 0.1276
# Epoch 2/20
# 132/132 [==============================] - 5s 19ms/step - loss: 20187.0879 - mean_squared_error: 20187.0898 - NSE: -344.8477 - r_square: 0.1444 - val_loss: 128651.2188 - val_mean_squared_error: 128651.2109 - val_NSE: -1963.2921 - val_r_square: 0.1129
# Epoch 3/20
# 132/132 [==============================] - 5s 15ms/step - loss: 605299.7500 - mean_squared_error: 605299.8125 - NSE: -8258.8125 - r_square: 0.1329 - val_loss: 616124.9375 - val_mean_squared_error: 616125.0625 - val_NSE: -8722.1533 - val_r_square: 0.0560

# %%
lstm_model = create_lstm_model()
lstm_history = compile_and_fit(lstm_model)
# Out:
# Epoch 1/20
# 132/132 [==============================] - 16s 39ms/step - loss: 44.3456 - mean_squared_error: 44.3456 - NSE: 0.4496 - r_square: 0.0757 - val_loss: 11.1797 - val_mean_squared_error: 11.1797 - val_NSE: 0.8599 - val_r_square: 0.0346
# Epoch 2/20
# 132/132 [==============================] - 6s 24ms/step - loss: 9.7569 - mean_squared_error: 9.7569 - NSE: 0.8304 - r_square: 0.1164 - val_loss: 10.4899 - val_mean_squared_error: 10.4899 - val_NSE: 0.8570 - val_r_square: 0.0449
# Epoch 3/20
# 132/132 [==============================] - 6s 22ms/step - loss: 9.5829 - mean_squared_error: 9.5829 - NSE: 0.8411 - r_square: 0.1123 - val_loss: 10.8550 - val_mean_squared_error: 10.8550 - val_NSE: 0.8655 - val_r_square: 0.0732
# Epoch 4/20
# 132/132 [==============================] - 6s 23ms/step - loss: 9.9395 - mean_squared_error: 9.9395 - NSE: 0.8370 - r_square: 0.1032 - val_loss: 10.7169 - val_mean_squared_error: 10.7169 - val_NSE: 0.8679 - val_r_square: 0.0757

# %% [markdown]
# ## Predictions

# %%
# paolo 2017
sto_nino_test_df = sto_nino_test[0]
sto_nino_test_df
# Out:
#          x         t  fric_coeff     slope  Rainfall_Aries  Rainfall_Boso  \
# 1    14420       0.0       0.033  0.000667               0              0
# 3    14420    3600.0       0.033  0.000667               0              0
# 5    14420    7200.0       0.033  0.000667               0              0
# 7    14420   10800.0       0.033  0.000667               0              0
# 9    14420   14400.0       0.033  0.000667               0              0
# ..     ...       ...         ...       ...             ...            ...
# 327  14420  586800.0       0.033  0.000667               0              0
# 329  14420  590400.0       0.033  0.000667               0              0
# 331  14420  594000.0       0.033  0.000667               0              0
# 333  14420  597600.0       0.033  0.000667               0              0
# 335  14420  601200.0       0.033  0.000667               0              1
#
#      Rainfall_Campana  Rainfall_Nangka  Rainfall_Oro  Waterlevel  Velocity
# 1                   0                0             0       12.74  0.046266
# 3                   0                0             0       12.71  0.044954
# 5                   0                0             0       12.70  0.044523
# 7                   0                0             0       12.70  0.044523
# 9                   0                0             0       12.69  0.044096
# ..                ...              ...           ...         ...       ...
# 327                 0                0             0       12.31  0.030064
# 329                 0                0             0       12.31  0.030064
# 331                 0                0             0       12.31  0.030064
# 333                 0                0             0       12.31  0.030064
# 335                 1                0             0       12.31  0.030064
#
# [168 rows x 11 columns]

# %%
sto_nino_y_true = sto_nino_test_df[['Waterlevel', 'Velocity']]
sto_nino_y_true = sto_nino_y_true.values
sto_nino_y_true
# Out:
# array([[12.74      ,  0.0462663 ],
#        [12.71      ,  0.04495427],
#        [12.7       ,  0.04452341],
#        [12.7       ,  0.04452341],
#        [12.69      ,  0.04409577],
#        [12.67      ,  0.04325006],
#        [12.66      ,  0.04283196],
#        [12.66      ,  0.04283196],
#        [12.64      ,  0.04200518],
#        [12.64      ,  0.04200518],
#        [12.63      ,  0.04159647],
#        [12.66      ,  0.04283196],
#        [12.66      ,  0.04283196],
#        [12.67      ,  0.04325006],
#        [12.65      ,  0.04241701],
#        [12.65      ,  0.04241701],
#        [12.64      ,  0.04200518],
#        [12.64      ,  0.04200518],
#        [12.63      ,  0.04159647],
#        [12.63      ,  0.04159647],
#        [12.61      ,  0.04078832],
#        [12.59      ,  0.03999242],
#        [12.58      ,  0.03959902],
#        [12.58      ,  0.03959902],
#        [12.57      ,  0.03920864],
#        [12.56      ,  0.03882125],
#        [12.55      ,  0.03843685],
#        [12.55      ,  0.03843685],
#        [12.53      ,  0.03767692],
#        [12.52      ,  0.03730136],
#        [12.52      ,  0.03730136],
#        [12.52      ,  0.03730136],
#        [12.52      ,  0.03730136],
#        [12.52      ,  0.03730136],
#        [12.51      ,  0.03692872],
#        [12.5       ,  0.03655897],
#        [12.5       ,  0.03655897],
#        [12.5       ,  0.03655897],
#        [12.51      ,  0.03692872],
#        [12.51      ,  0.03692872],
#        [12.49      ,  0.03619211],
#        [12.49      ,  0.03619211],
#        [12.5       ,  0.03655897],
#        [12.5       ,  0.03655897],
#        [12.5       ,  0.03655897],
#        [12.48      ,  0.03582812],
#        [12.46      ,  0.03510868],
#        [12.47      ,  0.03546698],
#        [12.48      ,  0.03582812],
#        [12.47      ,  0.03546698],
#        [12.47      ,  0.03546698],
#        [12.47      ,  0.03546698],
#        [12.46      ,  0.03510868],
#        [12.47      ,  0.03546698],
#        [12.48      ,  0.03582812],
#        [12.5       ,  0.03655897],
#        [12.5       ,  0.03655897],
#        [12.53      ,  0.03767692],
#        [12.54      ,  0.03805541],
#        [12.54      ,  0.03805541],
#        [12.54      ,  0.03805541],
#        [12.55      ,  0.03843685],
#        [12.55      ,  0.03843685],
#        [12.55      ,  0.03843685],
#        [12.55      ,  0.03843685],
#        [12.54      ,  0.03805541],
#        [12.53      ,  0.03767692],
#        [12.52      ,  0.03730136],
#        [12.5       ,  0.03655897],
#        [12.49      ,  0.03619211],
#        [12.49      ,  0.03619211],
#        [12.48      ,  0.03582812],
#        [12.46      ,  0.03510868],
#        [12.46      ,  0.03510868],
#        [12.46      ,  0.03510868],
#        [12.46      ,  0.03510868],
#        [12.46      ,  0.03510868],
#        [12.46      ,  0.03510868],
#        [12.45      ,  0.0347532 ],
#        [12.45      ,  0.0347532 ],
#        [12.45      ,  0.0347532 ],
#        [12.44      ,  0.03440052],
#        [12.44      ,  0.03440052],
#        [12.44      ,  0.03440052],
#        [12.44      ,  0.03440052],
#        [12.43      ,  0.03405063],
#        [12.43      ,  0.03405063],
#        [12.43      ,  0.03405063],
#        [12.43      ,  0.03405063],
#        [12.43      ,  0.03405063],
#        [12.43      ,  0.03405063],
#        [12.43      ,  0.03405063],
#        [12.42      ,  0.03370352],
#        [12.42      ,  0.03370352],
#        [12.41      ,  0.03335916],
#        [12.41      ,  0.03335916],
#        [12.41      ,  0.03335916],
#        [12.41      ,  0.03335916],
#        [12.4       ,  0.03301754],
#        [12.4       ,  0.03301754],
#        [12.39      ,  0.03267865],
#        [12.39      ,  0.03267865],
#        [12.39      ,  0.03267865],
#        [12.39      ,  0.03267865],
#        [12.38      ,  0.03234247],
#        [12.38      ,  0.03234247],
#        [12.38      ,  0.03234247],
#        [12.38      ,  0.03234247],
#        [12.38      ,  0.03234247],
#        [12.38      ,  0.03234247],
#        [12.38      ,  0.03234247],
#        [12.38      ,  0.03234247],
#        [12.38      ,  0.03234247],
#        [12.37      ,  0.03200899],
#        [12.37      ,  0.03200899],
#        [12.37      ,  0.03200899],
#        [12.37      ,  0.03200899],
#        [12.37      ,  0.03200899],
#        [12.37      ,  0.03200899],
#        [12.37      ,  0.03200899],
#        [12.37      ,  0.03200899],
#        [12.37      ,  0.03200899],
#        [12.37      ,  0.03200899],
#        [12.37      ,  0.03200899],
#        [12.37      ,  0.03200899],
#        [12.37      ,  0.03200899],
#        [12.37      ,  0.03200899],
#        [12.44      ,  0.03440052],
#        [12.63      ,  0.04159647],
#        [12.64      ,  0.04200518],
#        [12.64      ,  0.04200518],
#        [12.52      ,  0.03730136],
#        [12.51      ,  0.03692872],
#        [12.51      ,  0.03692872],
#        [12.5       ,  0.03655897],
#        [12.49      ,  0.03619211],
#        [12.38      ,  0.03234247],
#        [12.58      ,  0.03959902],
#        [12.38      ,  0.03234247],
#        [12.38      ,  0.03234247],
#        [12.38      ,  0.03234247],
#        [12.39      ,  0.03267865],
#        [12.38      ,  0.03234247],
#        [12.37      ,  0.03200899],
#        [12.37      ,  0.03200899],
#        [12.37      ,  0.03200899],
#        [12.36      ,  0.03167819],
#        [12.36      ,  0.03167819],
#        [12.36      ,  0.03167819],
#        [12.36      ,  0.03167819],
#        [12.35      ,  0.03135005],
#        [12.34      ,  0.03102456],
#        [12.34      ,  0.03102456],
#        [12.31      ,  0.03006385],
#        [12.31      ,  0.03006385],
#        [12.31      ,  0.03006385],
#        [12.31      ,  0.03006385],
#        [12.31      ,  0.03006385],
#        [12.31      ,  0.03006385],
#        [12.31      ,  0.03006385],
#        [12.31      ,  0.03006385],
#        [12.31      ,  0.03006385],
#        [12.31      ,  0.03006385],
#        [12.31      ,  0.03006385],
#        [12.31      ,  0.03006385],
#        [12.31      ,  0.03006385],
#        [12.31      ,  0.03006385],
#        [12.31      ,  0.03006385]])

# %%
sto_nino_y_true_h = sto_nino_y_true[1:,0]
sto_nino_y_true_v = sto_nino_y_true[1:,1]

# %%
np.set_printoptions(suppress=True)

# %%
test_event = sto_nino_test_ds['paolo_2017']
test_event
# Out:
# <_MapDataset element_spec=(TensorSpec(shape=(None, 6, 11), dtype=tf.float32, name=None), TensorSpec(shape=(None, 6, 2), dtype=tf.float32, name=None))>

# %%
for x, y in test_event.take(1):
    print(x[:5])
    print(lstm_model(x[:5]))
    print(y[:5])
    break
# Out:
# tf.Tensor(
# [[[14420.             0.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.74           0.0462663 ]
#   [14420.          3600.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.71           0.04495427]
#   [14420.          7200.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.7            0.04452341]
#   [14420.         10800.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.7            0.04452341]
#   [14420.         14400.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.69           0.04409577]
#   [14420.         18000.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.67           0.04325006]]
#
#  [[14420.          3600.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.71           0.04495427]
#   [14420.          7200.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.7            0.04452341]
#   [14420.         10800.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.7            0.04452341]
#   [14420.         14400.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.69           0.04409577]
#   [14420.         18000.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.67           0.04325006]
#   [14420.         21600.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.66           0.04283196]]
#
#  [[14420.          7200.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.7            0.04452341]
#   [14420.         10800.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.7            0.04452341]
#   [14420.         14400.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.69           0.04409577]
#   [14420.         18000.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.67           0.04325006]
#   [14420.         21600.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.66           0.04283196]
#   [14420.         25200.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.66           0.04283196]]
#
#  [[14420.         10800.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.7            0.04452341]
#   [14420.         14400.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.69           0.04409577]
#   [14420.         18000.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.67           0.04325006]
#   [14420.         21600.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.66           0.04283196]
#   [14420.         25200.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.66           0.04283196]
#   [14420.         28800.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.64           0.04200518]]
#
#  [[14420.         14400.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.69           0.04409577]
#   [14420.         18000.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.67           0.04325006]
#   [14420.         21600.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.66           0.04283196]
#   [14420.         25200.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.66           0.04283196]
#   [14420.         28800.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.64           0.04200518]
#   [14420.         32400.             0.033          0.00066667
#        0.             0.             0.             0.
#        0.            12.64           0.04200518]]], shape=(5, 6, 11), dtype=float32)
# tf.Tensor(
# [[[ 7.896962    0.19146784]
#   [12.308539    0.20650183]
#   [12.670744    0.15127206]
#   [12.698277   -0.13894197]
#   [12.785709   -0.03456389]
#   [12.997253   -0.13632728]]
#
#  [[10.960688    0.04455185]
#   [12.305614    0.00792058]
#   [12.323184   -0.27184713]
#   [12.39698     0.08128224]
#   [12.636353    0.03554305]
#   [12.135419   -0.04689668]]
#
#  [[10.339954    0.1050289 ]
#   [11.788987   -0.12882032]
#   [12.122879    0.18272792]
#   [12.582376    0.10428686]
#   [12.12904     0.01976016]
#   [11.730135    0.01180399]]
#
#  [[10.465331   -0.15257475]
#   [11.586117    0.17896941]
#   [12.159492    0.10699855]
#   [11.996678    0.02167294]
#   [11.595371    0.01520745]
#   [12.763439    0.08054234]]
#
#  [[ 9.061559    0.11696805]
#   [10.537802    0.07511267]
#   [11.601136    0.02154015]
#   [11.216446    0.01961482]
#   [12.426013    0.09015097]
#   [13.187662    0.12660238]]], shape=(5, 6, 2), dtype=float32)
# tf.Tensor(
# [[[12.71        0.04495427]
#   [12.7         0.04452341]
#   [12.7         0.04452341]
#   [12.69        0.04409577]
#   [12.67        0.04325006]
#   [12.66        0.04283196]]
#
#  [[12.7         0.04452341]
#   [12.7         0.04452341]
#   [12.69        0.04409577]
#   [12.67        0.04325006]
#   [12.66        0.04283196]
#   [12.66        0.04283196]]
#
#  [[12.7         0.04452341]
#   [12.69        0.04409577]
#   [12.67        0.04325006]
#   [12.66        0.04283196]
#   [12.66        0.04283196]
#   [12.64        0.04200518]]
#
#  [[12.69        0.04409577]
#   [12.67        0.04325006]
#   [12.66        0.04283196]
#   [12.66        0.04283196]
#   [12.64        0.04200518]
#   [12.64        0.04200518]]
#
#  [[12.67        0.04325006]
#   [12.66        0.04283196]
#   [12.66        0.04283196]
#   [12.64        0.04200518]
#   [12.64        0.04200518]
#   [12.63        0.04159647]]], shape=(5, 6, 2), dtype=float32)

# %%
sto_nino_y_pred_h = []
sto_nino_y_pred_v = []
batch_num = 1

for x, y in test_event:
    predictions = lstm_model(x)
    
    if batch_num == 1:
        for i in range(len(predictions[0])):
            sto_nino_y_pred_h.append(predictions[0][i][0])
            sto_nino_y_pred_v.append(predictions[0][i][1])
            
        for i in range(1, len(predictions)):
            sto_nino_y_pred_h.append(predictions[i][-1][0])
            sto_nino_y_pred_v.append(predictions[i][-1][1])
            
        batch_num += 1
        
    else:
        for i in range(len(predictions)):
            sto_nino_y_pred_h.append(predictions[i][-1][0])
            sto_nino_y_pred_v.append(predictions[i][-1][1])
            
sto_nino_y_pred_h = np.array(sto_nino_y_pred_h)
sto_nino_y_pred_v = np.array(sto_nino_y_pred_v)

# %%
sto_nino_y_pred_h
# Out:
# array([ 7.896962, 12.308539, 12.670744, 12.698277, 12.785709, 12.997253,
#        12.135419, 11.730135, 12.763439, 13.187662, 13.193377, 13.972836,
#        13.765643, 13.733868, 14.692375, 14.691782, 14.691702, 14.691702,
#        15.825019, 15.825544, 15.853661, 16.63047 , 17.39866 , 17.423933,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406, 17.424406,
#        17.424406, 17.424406, 17.424406, 17.424406, 17.424406],
#       dtype=float32)

# %%
sto_nino_y_pred_h.shape
# Out:
# (167,)

# %%
sto_nino_SS_res_h = np.sum(np.square(sto_nino_y_true_h - sto_nino_y_pred_h)) 
sto_nino_SS_tot_h = np.sum(np.square(sto_nino_y_true_h - np.mean(sto_nino_y_true_h))) 

sto_nino_nse_h =  1 - sto_nino_SS_res_h/sto_nino_SS_tot_h
sto_nino_nse_h
# Out:
# -2044.1067563593995

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(sto_nino_y_pred_h, label='Predicted values')
plt.plot(sto_nino_y_true_h, label='True values')
plt.legend()
plt.show()
